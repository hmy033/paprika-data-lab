# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import pi
import time

# %%
Netflix = pd.read_csv("/content/drive/MyDrive/paprika/ViewingActivity.csv")
Netflix.head()
# Out:
#   Profile Name           Start Time  Duration  \
# 0        guest  2021-05-31 02:25:20  00:00:05
# 1        guest  2021-05-30 14:08:38  00:00:04
# 2        guest  2021-05-30 14:08:20  00:00:04
# 3        guest  2021-05-30 14:06:08  00:01:54
# 4        guest  2021-05-30 14:05:48  00:00:17
#
#                                     Attributes  \
# 0              Autoplayed: user action: None;
# 1  Autoplayed: user action: User_Interaction;
# 2              Autoplayed: user action: None;
# 3  Autoplayed: user action: User_Interaction;
# 4              Autoplayed: user action: None;
#
#                                       Title Supplemental Video Type  \
# 0         Move to Heaven: Season 1 (Hook 1)                    HOOK
# 1                                 가질 수 없는 너                     NaN
# 2  Gatao - The Last Stray_hook_primary_16x9                    HOOK
# 3               자객 오육칠: 시즌 1: 부자가 되는 법 (1화)                     NaN
# 4                        시즌 2 (예고편): 자객 오육칠                 TRAILER
#
#                            Device Type  Bookmark Latest Bookmark  \
# 0  Netflix Chrome MAC (Cadmium) HTML 5  00:00:05        00:00:05
# 1                 Safari MAC (Cadmium)  00:00:04        00:00:04
# 2                 Safari MAC (Cadmium)  00:00:04        00:00:04
# 3                 Safari MAC (Cadmium)  00:01:54        00:01:54
# 4                 Safari MAC (Cadmium)  00:00:17        00:00:17
#
#                    Country
# 0  KR (Korea, Republic of)
# 1  KR (Korea, Republic of)
# 2  KR (Korea, Republic of)
# 3  KR (Korea, Republic of)
# 4  KR (Korea, Republic of)

# %%
Netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19161 entries, 0 to 19160
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Profile Name             19161 non-null  object
#  1   Start Time               19161 non-null  object
#  2   Duration                 19161 non-null  object
#  3   Attributes               8441 non-null   object
#  4   Title                    19161 non-null  object
#  5   Supplemental Video Type  3810 non-null   object
#  6   Device Type              19160 non-null  object
#  7   Bookmark                 19161 non-null  object
#  8   Latest Bookmark          19161 non-null  object
#  9   Country                  19161 non-null  object
# dtypes: object(10)
# memory usage: 1.5+ MB

# %% [markdown]
# ## Start Time을 DateTime type으로 바꾸기

# %%
Netflix["Start Time"] = pd.to_datetime(Netflix["Start Time"])

# %%
Netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19161 entries, 0 to 19160
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Profile Name             19161 non-null  object
#  1   Start Time               19161 non-null  datetime64[ns]
#  2   Duration                 19161 non-null  object
#  3   Attributes               8441 non-null   object
#  4   Title                    19161 non-null  object
#  5   Supplemental Video Type  3810 non-null   object
#  6   Device Type              19160 non-null  object
#  7   Bookmark                 19161 non-null  object
#  8   Latest Bookmark          19161 non-null  object
#  9   Country                  19161 non-null  object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 1.5+ MB

# %% [markdown]
# ## 날짜 분리
# 연도 / 월 / 일 / 요일

# %%
Netflix["Year"] = Netflix["Start Time"].dt.year
Netflix["Month"] = Netflix["Start Time"].dt.month
Netflix["Day"] = Netflix["Start Time"].dt.day
Netflix["Day_name"] = Netflix["Start Time"].dt.day_name()
Netflix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93fa8df724f7> in <module>()
# ----> 1 Netflix["Year"] = Netflix["Start Time"].dt.year
#       2 Netflix["Month"] = Netflix["Start Time"].dt.month
#       3 Netflix["Day"] = Netflix["Start Time"].dt.day
#       4 Netflix["Day_name"] = Netflix["Start Time"].dt.day_name()
#       5 Netflix
#
# NameError: name 'Netflix' is not defined

# %% [markdown]
# ## 시간 분리
# 시 / 분 / 초

# %%
Netflix["Hour"] = Netflix["Start Time"].dt.hour
Netflix["Minute"] = Netflix["Start Time"].dt.minute
Netflix["Second"] = Netflix["Start Time"].dt.second
Netflix
# Out:
#       Profile Name          Start Time  Duration  \
# 0            guest 2021-05-31 02:25:20  00:00:05
# 1            guest 2021-05-30 14:08:38  00:00:04
# 2            guest 2021-05-30 14:08:20  00:00:04
# 3            guest 2021-05-30 14:06:08  00:01:54
# 4            guest 2021-05-30 14:05:48  00:00:17
# ...            ...                 ...       ...
# 19156          김지은 2019-02-09 04:25:19  00:00:23
# 19157          김지은 2019-02-09 04:20:35  00:00:57
# 19158          김지은 2019-02-09 04:08:47  00:00:18
# 19159          김지은 2019-02-09 03:10:57  00:00:11
# 19160          김지은 2019-02-09 03:10:37  00:00:06
#
#                                         Attributes  \
# 0                  Autoplayed: user action: None;
# 1      Autoplayed: user action: User_Interaction;
# 2                  Autoplayed: user action: None;
# 3      Autoplayed: user action: User_Interaction;
# 4                  Autoplayed: user action: None;
# ...                                            ...
# 19156                                          NaN
# 19157                                          NaN
# 19158                                          NaN
# 19159                                          NaN
# 19160                                          NaN
#
#                                           Title Supplemental Video Type  \
# 0             Move to Heaven: Season 1 (Hook 1)                    HOOK
# 1                                     가질 수 없는 너                     NaN
# 2      Gatao - The Last Stray_hook_primary_16x9                    HOOK
# 3                   자객 오육칠: 시즌 1: 부자가 되는 법 (1화)                     NaN
# 4                            시즌 2 (예고편): 자객 오육칠                 TRAILER
# ...                                         ...                     ...
# 19156               릭 앤 모티: 시즌 1: 파일럿 에피소드 (1화)                     NaN
# 19157                오티스의 비밀 상담소: 시즌 1: 1화 (1화)                     NaN
# 19158                         킹덤: 시즌 1: 1화 (1화)                     NaN
# 19159                         킹덤: 시즌 1: 1화 (1화)                     NaN
# 19160                         킹덤: 시즌 1: 1화 (1화)                     NaN
#
#                                Device Type  Bookmark  Latest Bookmark  \
# 0      Netflix Chrome MAC (Cadmium) HTML 5  00:00:05         00:00:05
# 1                     Safari MAC (Cadmium)  00:00:04         00:00:04
# 2                     Safari MAC (Cadmium)  00:00:04         00:00:04
# 3                     Safari MAC (Cadmium)  00:01:54         00:01:54
# 4                     Safari MAC (Cadmium)  00:00:17         00:00:17
# ...                                    ...       ...              ...
# 19156       Netflix Android STB L3 Android  00:00:23  Not latest view
# 19157       Netflix Android STB L3 Android  00:00:57  Not latest view
# 19158       Netflix Android STB L3 Android  00:00:23         00:00:23
# 19159                 Apple iPhone X (GSM)  00:00:11  Not latest view
# 19160                 Apple iPhone X (GSM)  00:00:06  Not latest view
#
#                        Country  Year  Month  Day  Day_name  Hour  Minute  \
# 0      KR (Korea, Republic of)  2021      5   31    Monday     2      25
# 1      KR (Korea, Republic of)  2021      5   30    Sunday    14       8
# 2      KR (Korea, Republic of)  2021      5   30    Sunday    14       8
# 3      KR (Korea, Republic of)  2021      5   30    Sunday    14       6
# 4      KR (Korea, Republic of)  2021      5   30    Sunday    14       5
# ...                        ...   ...    ...  ...       ...   ...     ...
# 19156  KR (Korea, Republic of)  2019      2    9  Saturday     4      25
# 19157  KR (Korea, Republic of)  2019      2    9  Saturday     4      20
# 19158  KR (Korea, Republic of)  2019      2    9  Saturday     4       8
# 19159  KR (Korea, Republic of)  2019      2    9  Saturday     3      10
# 19160  KR (Korea, Republic of)  2019      2    9  Saturday     3      10
#
#        Second
# 0          20
# 1          38
# 2          20
# 3           8
# 4          48
# ...       ...
# 19156      19
# 19157      35
# 19158      47
# 19159      57
# 19160      37
#
# [19161 rows x 17 columns]

# %% [markdown]
# # 1. 요일 별 시청 시간(movie, drama 합쳐서)(중복값 제거 X)
#
# 요일별로 duration 합치기
#
# 선형그래프

# %%
day_name = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# %%
Netflix["Duration_hour"] = Netflix['Duration'].apply(lambda x : x.split(':')[0])
Netflix["Duration_min"] = Netflix['Duration'].apply(lambda x : x.split(':')[1])
Netflix["Duration_sec"] = Netflix['Duration'].apply(lambda x : x.split(':')[2])
Netflix.head()
# Out:
#   Profile Name          Start Time  Duration  \
# 0        guest 2021-05-31 02:25:20  00:00:05
# 1        guest 2021-05-30 14:08:38  00:00:04
# 2        guest 2021-05-30 14:08:20  00:00:04
# 3        guest 2021-05-30 14:06:08  00:01:54
# 4        guest 2021-05-30 14:05:48  00:00:17
#
#                                     Attributes  \
# 0              Autoplayed: user action: None;
# 1  Autoplayed: user action: User_Interaction;
# 2              Autoplayed: user action: None;
# 3  Autoplayed: user action: User_Interaction;
# 4              Autoplayed: user action: None;
#
#                                       Title Supplemental Video Type  \
# 0         Move to Heaven: Season 1 (Hook 1)                    HOOK
# 1                                 가질 수 없는 너                     NaN
# 2  Gatao - The Last Stray_hook_primary_16x9                    HOOK
# 3               자객 오육칠: 시즌 1: 부자가 되는 법 (1화)                     NaN
# 4                        시즌 2 (예고편): 자객 오육칠                 TRAILER
#
#                            Device Type  Bookmark Latest Bookmark  \
# 0  Netflix Chrome MAC (Cadmium) HTML 5  00:00:05        00:00:05
# 1                 Safari MAC (Cadmium)  00:00:04        00:00:04
# 2                 Safari MAC (Cadmium)  00:00:04        00:00:04
# 3                 Safari MAC (Cadmium)  00:01:54        00:01:54
# 4                 Safari MAC (Cadmium)  00:00:17        00:00:17
#
#                    Country  Year  Month  Day Day_name  Hour  Minute  Second  \
# 0  KR (Korea, Republic of)  2021      5   31   Monday     2      25      20
# 1  KR (Korea, Republic of)  2021      5   30   Sunday    14       8      38
# 2  KR (Korea, Republic of)  2021      5   30   Sunday    14       8      20
# 3  KR (Korea, Republic of)  2021      5   30   Sunday    14       6       8
# 4  KR (Korea, Republic of)  2021      5   30   Sunday    14       5      48
#
#   Duration_hour Duration_min Duration_sec
# 0            00           00           05
# 1            00           00           04
# 2            00           00           04
# 3            00           01           54
# 4            00           00           17

# %%
Netflix['Duration_sec_sum'] = Netflix["Duration_sec"].map(int) + Netflix["Duration_min"].apply(lambda x : int(x)*60) + Netflix["Duration_hour"].apply(lambda x : int(x)*3600)
Netflix.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-84853463baa7> in <module>()
# ----> 1 Netflix['Duration_sec_sum'] = Netflix["Duration_sec"].map(int) + Netflix["Duration_min"].apply(lambda x : int(x)*60) + Netflix["Duration_hour"].apply(lambda x : int(x)*3600)
#       2 Netflix.head()
#
# NameError: name 'Netflix' is not defined

# %% [markdown]
# ### duration 초(시간단위)로 바꾸기

# %%
Duration_seconds_sum = Netflix.groupby(["Day_name"])['Duration_sec_sum'].sum()
Duration_seconds_sum
# Out:
# Day_name
# Friday       1887486
# Monday       1412542
# Saturday     2973857
# Sunday       2585885
# Thursday     1712603
# Tuesday      1679127
# Wednesday    1606501
# Name: Duration_sec_sum, dtype: int64

# %%
plt.figure(figsize=(16, 8))
Duration_seconds_sum.plot()

# %% [markdown]
# ### duration 분(시간단위)로 바꾸기

# %%
Duration_min_sum = round(Netflix.groupby(["Day_name"])['Duration_sec_sum'].sum()/60,2)
Duration_min_sum
# Out:
# Day_name
# Friday       31458.10
# Monday       23542.37
# Saturday     49564.28
# Sunday       43098.08
# Thursday     28543.38
# Tuesday      27985.45
# Wednesday    26775.02
# Name: Duration_sec_sum, dtype: float64

# %%
plt.figure(figsize=(16, 8))
plt.plot(Duration_min_sum)

# %% [markdown]
# ### duration 시(시간단위)로 바꾸기

# %%
Duration_hour_sum = round(Netflix.groupby(["Day_name"])['Duration_sec_sum'].sum()/3600,2)
Duration_hour_sum
# Out:
# Day_name
# Friday       524.30
# Monday       392.37
# Saturday     826.07
# Sunday       718.30
# Thursday     475.72
# Tuesday      466.42
# Wednesday    446.25
# Name: Duration_sec_sum, dtype: float64

# %%
plt.figure(figsize=(16, 8))
plt.plot(Duration_hour_sum)

# %% [markdown]
# # 2. 가장 많은 시간을 소비한 TV 시리즈 Top5의 각 소요 시간의 합
# bar chart

# %%
Netflix
# Out:
#       Profile Name          Start Time  Duration  \
# 0            guest 2021-05-31 02:25:20  00:00:05
# 1            guest 2021-05-30 14:08:38  00:00:04
# 2            guest 2021-05-30 14:08:20  00:00:04
# 3            guest 2021-05-30 14:06:08  00:01:54
# 4            guest 2021-05-30 14:05:48  00:00:17
# ...            ...                 ...       ...
# 19156          김지은 2019-02-09 04:25:19  00:00:23
# 19157          김지은 2019-02-09 04:20:35  00:00:57
# 19158          김지은 2019-02-09 04:08:47  00:00:18
# 19159          김지은 2019-02-09 03:10:57  00:00:11
# 19160          김지은 2019-02-09 03:10:37  00:00:06
#
#                                         Attributes  \
# 0                  Autoplayed: user action: None;
# 1      Autoplayed: user action: User_Interaction;
# 2                  Autoplayed: user action: None;
# 3      Autoplayed: user action: User_Interaction;
# 4                  Autoplayed: user action: None;
# ...                                            ...
# 19156                                          NaN
# 19157                                          NaN
# 19158                                          NaN
# 19159                                          NaN
# 19160                                          NaN
#
#                                           Title Supplemental Video Type  \
# 0             Move to Heaven: Season 1 (Hook 1)                    HOOK
# 1                                     가질 수 없는 너                     NaN
# 2      Gatao - The Last Stray_hook_primary_16x9                    HOOK
# 3                   자객 오육칠: 시즌 1: 부자가 되는 법 (1화)                     NaN
# 4                            시즌 2 (예고편): 자객 오육칠                 TRAILER
# ...                                         ...                     ...
# 19156               릭 앤 모티: 시즌 1: 파일럿 에피소드 (1화)                     NaN
# 19157                오티스의 비밀 상담소: 시즌 1: 1화 (1화)                     NaN
# 19158                         킹덤: 시즌 1: 1화 (1화)                     NaN
# 19159                         킹덤: 시즌 1: 1화 (1화)                     NaN
# 19160                         킹덤: 시즌 1: 1화 (1화)                     NaN
#
#                                Device Type  Bookmark  Latest Bookmark  \
# 0      Netflix Chrome MAC (Cadmium) HTML 5  00:00:05         00:00:05
# 1                     Safari MAC (Cadmium)  00:00:04         00:00:04
# 2                     Safari MAC (Cadmium)  00:00:04         00:00:04
# 3                     Safari MAC (Cadmium)  00:01:54         00:01:54
# 4                     Safari MAC (Cadmium)  00:00:17         00:00:17
# ...                                    ...       ...              ...
# 19156       Netflix Android STB L3 Android  00:00:23  Not latest view
# 19157       Netflix Android STB L3 Android  00:00:57  Not latest view
# 19158       Netflix Android STB L3 Android  00:00:23         00:00:23
# 19159                 Apple iPhone X (GSM)  00:00:11  Not latest view
# 19160                 Apple iPhone X (GSM)  00:00:06  Not latest view
#
#                        Country  ...  Month  Day  Day_name Hour  Minute  \
# 0      KR (Korea, Republic of)  ...      5   31    Monday    2      25
# 1      KR (Korea, Republic of)  ...      5   30    Sunday   14       8
# 2      KR (Korea, Republic of)  ...      5   30    Sunday   14       8
# 3      KR (Korea, Republic of)  ...      5   30    Sunday   14       6
# 4      KR (Korea, Republic of)  ...      5   30    Sunday   14       5
# ...                        ...  ...    ...  ...       ...  ...     ...
# 19156  KR (Korea, Republic of)  ...      2    9  Saturday    4      25
# 19157  KR (Korea, Republic of)  ...      2    9  Saturday    4      20
# 19158  KR (Korea, Republic of)  ...      2    9  Saturday    4       8
# 19159  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
# 19160  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
#
#        Second  Duration_hour Duration_min Duration_sec Duration_sec_sum
# 0          20             00           00           05                5
# 1          38             00           00           04                4
# 2          20             00           00           04                4
# 3           8             00           01           54              114
# 4          48             00           00           17               17
# ...       ...            ...          ...          ...              ...
# 19156      19             00           00           23               23
# 19157      35             00           00           57               57
# 19158      47             00           00           18               18
# 19159      57             00           00           11               11
# 19160      37             00           00           06                6
#
# [19161 rows x 21 columns]

# %%
Drama = Netflix.loc[Netflix["Title"].str.contains(':')]
Drama
# Out:
#       Profile Name          Start Time  Duration  \
# 0            guest 2021-05-31 02:25:20  00:00:05
# 3            guest 2021-05-30 14:06:08  00:01:54
# 4            guest 2021-05-30 14:05:48  00:00:17
# 6            guest 2021-05-30 14:05:01  00:00:07
# 10           guest 2021-05-30 11:21:17  00:01:31
# ...            ...                 ...       ...
# 19156          김지은 2019-02-09 04:25:19  00:00:23
# 19157          김지은 2019-02-09 04:20:35  00:00:57
# 19158          김지은 2019-02-09 04:08:47  00:00:18
# 19159          김지은 2019-02-09 03:10:57  00:00:11
# 19160          김지은 2019-02-09 03:10:37  00:00:06
#
#                                         Attributes  \
# 0                  Autoplayed: user action: None;
# 3      Autoplayed: user action: User_Interaction;
# 4                  Autoplayed: user action: None;
# 6                  Autoplayed: user action: None;
# 10                 Autoplayed: user action: None;
# ...                                            ...
# 19156                                          NaN
# 19157                                          NaN
# 19158                                          NaN
# 19159                                          NaN
# 19160                                          NaN
#
#                                            Title Supplemental Video Type  \
# 0              Move to Heaven: Season 1 (Hook 1)                    HOOK
# 3                    자객 오육칠: 시즌 1: 부자가 되는 법 (1화)                     NaN
# 4                             시즌 2 (예고편): 자객 오육칠                 TRAILER
# 6      Nothing But Thirty: Season 1_hook_01_16x9                    HOOK
# 10                       우주를 누비는 쏙독새: 시즌 1 (예고편)                 TRAILER
# ...                                          ...                     ...
# 19156                릭 앤 모티: 시즌 1: 파일럿 에피소드 (1화)                     NaN
# 19157                 오티스의 비밀 상담소: 시즌 1: 1화 (1화)                     NaN
# 19158                          킹덤: 시즌 1: 1화 (1화)                     NaN
# 19159                          킹덤: 시즌 1: 1화 (1화)                     NaN
# 19160                          킹덤: 시즌 1: 1화 (1화)                     NaN
#
#                                Device Type  Bookmark  Latest Bookmark  \
# 0      Netflix Chrome MAC (Cadmium) HTML 5  00:00:05         00:00:05
# 3                     Safari MAC (Cadmium)  00:01:54         00:01:54
# 4                     Safari MAC (Cadmium)  00:00:17         00:00:17
# 6                     Safari MAC (Cadmium)  00:00:07         00:00:07
# 10                    Safari MAC (Cadmium)  00:01:32         00:01:32
# ...                                    ...       ...              ...
# 19156       Netflix Android STB L3 Android  00:00:23  Not latest view
# 19157       Netflix Android STB L3 Android  00:00:57  Not latest view
# 19158       Netflix Android STB L3 Android  00:00:23         00:00:23
# 19159                 Apple iPhone X (GSM)  00:00:11  Not latest view
# 19160                 Apple iPhone X (GSM)  00:00:06  Not latest view
#
#                        Country  ...  Month  Day  Day_name Hour  Minute  \
# 0      KR (Korea, Republic of)  ...      5   31    Monday    2      25
# 3      KR (Korea, Republic of)  ...      5   30    Sunday   14       6
# 4      KR (Korea, Republic of)  ...      5   30    Sunday   14       5
# 6      KR (Korea, Republic of)  ...      5   30    Sunday   14       5
# 10     KR (Korea, Republic of)  ...      5   30    Sunday   11      21
# ...                        ...  ...    ...  ...       ...  ...     ...
# 19156  KR (Korea, Republic of)  ...      2    9  Saturday    4      25
# 19157  KR (Korea, Republic of)  ...      2    9  Saturday    4      20
# 19158  KR (Korea, Republic of)  ...      2    9  Saturday    4       8
# 19159  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
# 19160  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
#
#        Second  Duration_hour Duration_min Duration_sec Duration_sec_sum
# 0          20             00           00           05                5
# 3           8             00           01           54              114
# 4          48             00           00           17               17
# 6           1             00           00           07                7
# 10         17             00           01           31               91
# ...       ...            ...          ...          ...              ...
# 19156      19             00           00           23               23
# 19157      35             00           00           57               57
# 19158      47             00           00           18               18
# 19159      57             00           00           11               11
# 19160      37             00           00           06                6
#
# [15953 rows x 21 columns]

# %% [markdown]
# ## 예고편 제거

# %%
pd.set_option('display.max_rows',None)

# %%
Drama["Supplemental Video Type"].unique()
# Out:
# array(['HOOK', nan, 'TRAILER', 'TEASER_TRAILER', 'PREVIEW', 'RECAP',
#        'CINEMAGRAPH', 'PROMOTIONAL', 'TUTORIAL'], dtype=object)

# %%
re_Drama = Drama.loc[Drama["Supplemental Video Type"].isnull()]
re_Drama = re_Drama.reset_index(drop=True)
re_Drama
# Out:
#       Profile Name          Start Time  Duration  \
# 0            guest 2021-05-30 14:06:08  00:01:54
# 1            guest 2020-09-28 08:51:09  00:41:18
# 2            guest 2020-09-28 07:54:05  00:57:03
# 3            guest 2020-09-26 18:16:04  00:03:18
# 4            guest 2020-09-26 17:20:56  00:18:46
# ...            ...                 ...       ...
# 13216          김지은 2019-02-09 04:25:19  00:00:23
# 13217          김지은 2019-02-09 04:20:35  00:00:57
# 13218          김지은 2019-02-09 04:08:47  00:00:18
# 13219          김지은 2019-02-09 03:10:57  00:00:11
# 13220          김지은 2019-02-09 03:10:37  00:00:06
#
#                                         Attributes  \
# 0      Autoplayed: user action: User_Interaction;
# 1                  Autoplayed: user action: None;
# 2                                              NaN
# 3                                              NaN
# 4                  Autoplayed: user action: None;
# ...                                            ...
# 13216                                          NaN
# 13217                                          NaN
# 13218                                          NaN
# 13219                                          NaN
# 13220                                          NaN
#
#                              Title Supplemental Video Type  \
# 0      자객 오육칠: 시즌 1: 부자가 되는 법 (1화)                     NaN
# 1         슬기로운 의사생활: 시즌 1: 5화 (5화)                     NaN
# 2         슬기로운 의사생활: 시즌 1: 4화 (4화)                     NaN
# 3         슬기로운 의사생활: 시즌 1: 4화 (4화)                     NaN
# 4         슬기로운 의사생활: 시즌 1: 4화 (4화)                     NaN
# ...                            ...                     ...
# 13216  릭 앤 모티: 시즌 1: 파일럿 에피소드 (1화)                     NaN
# 13217   오티스의 비밀 상담소: 시즌 1: 1화 (1화)                     NaN
# 13218            킹덤: 시즌 1: 1화 (1화)                     NaN
# 13219            킹덤: 시즌 1: 1화 (1화)                     NaN
# 13220            킹덤: 시즌 1: 1화 (1화)                     NaN
#
#                           Device Type  Bookmark  Latest Bookmark  \
# 0                Safari MAC (Cadmium)  00:01:54         00:01:54
# 1                Safari MAC (Cadmium)  00:41:28         00:41:28
# 2                Safari MAC (Cadmium)  01:19:17         01:19:17
# 3                Safari MAC (Cadmium)  00:22:15  Not latest view
# 4                Safari MAC (Cadmium)  00:18:56  Not latest view
# ...                               ...       ...              ...
# 13216  Netflix Android STB L3 Android  00:00:23  Not latest view
# 13217  Netflix Android STB L3 Android  00:00:57  Not latest view
# 13218  Netflix Android STB L3 Android  00:00:23         00:00:23
# 13219            Apple iPhone X (GSM)  00:00:11  Not latest view
# 13220            Apple iPhone X (GSM)  00:00:06  Not latest view
#
#                        Country  ...  Month  Day  Day_name Hour  Minute  \
# 0      KR (Korea, Republic of)  ...      5   30    Sunday   14       6
# 1      KR (Korea, Republic of)  ...      9   28    Monday    8      51
# 2      KR (Korea, Republic of)  ...      9   28    Monday    7      54
# 3      KR (Korea, Republic of)  ...      9   26  Saturday   18      16
# 4      KR (Korea, Republic of)  ...      9   26  Saturday   17      20
# ...                        ...  ...    ...  ...       ...  ...     ...
# 13216  KR (Korea, Republic of)  ...      2    9  Saturday    4      25
# 13217  KR (Korea, Republic of)  ...      2    9  Saturday    4      20
# 13218  KR (Korea, Republic of)  ...      2    9  Saturday    4       8
# 13219  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
# 13220  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
#
#        Second  Duration_hour Duration_min Duration_sec Duration_sec_sum
# 0           8             00           01           54              114
# 1           9             00           41           18             2478
# 2           5             00           57           03             3423
# 3           4             00           03           18              198
# 4          56             00           18           46             1126
# ...       ...            ...          ...          ...              ...
# 13216      19             00           00           23               23
# 13217      35             00           00           57               57
# 13218      47             00           00           18               18
# 13219      57             00           00           11               11
# 13220      37             00           00           06                6
#
# [13221 rows x 21 columns]

# %%
len(re_Drama)
# Out:
# 13221

# %%
Title_list = list(re_Drama["Title"])
T_list = []
for i in range(len(Title_list)):
  T_list.append(Title_list[i].split(": "))

# %%
Title_df = pd.DataFrame(T_list, columns=["title","season", "episode", "episode2","episode3","episode4"])
Title_df
# Out:
#              title season        episode episode2 episode3 episode4
# 0           자객 오육칠   시즌 1  부자가 되는 법 (1화)     None     None     None
# 1        슬기로운 의사생활   시즌 1        5화 (5화)     None     None     None
# 2        슬기로운 의사생활   시즌 1        4화 (4화)     None     None     None
# 3        슬기로운 의사생활   시즌 1        4화 (4화)     None     None     None
# 4        슬기로운 의사생활   시즌 1        4화 (4화)     None     None     None
# ...            ...    ...            ...      ...      ...      ...
# 13216       릭 앤 모티   시즌 1  파일럿 에피소드 (1화)     None     None     None
# 13217  오티스의 비밀 상담소   시즌 1        1화 (1화)     None     None     None
# 13218           킹덤   시즌 1        1화 (1화)     None     None     None
# 13219           킹덤   시즌 1        1화 (1화)     None     None     None
# 13220           킹덤   시즌 1        1화 (1화)     None     None     None
#
# [13221 rows x 6 columns]

# %%
len(Title_df)
# Out:
# 13221

# %%
title = pd.DataFrame(Title_df["title"])
title
# Out:
#              title
# 0           자객 오육칠
# 1        슬기로운 의사생활
# 2        슬기로운 의사생활
# 3        슬기로운 의사생활
# 4        슬기로운 의사생활
# ...            ...
# 13216       릭 앤 모티
# 13217  오티스의 비밀 상담소
# 13218           킹덤
# 13219           킹덤
# 13220           킹덤
#
# [13221 rows x 1 columns]

# %%
total_Drama = pd.concat([re_Drama,title], axis=1)
total_Drama.head()
# Out:
#   Profile Name          Start Time  Duration  \
# 0        guest 2021-05-30 14:06:08  00:01:54
# 1        guest 2020-09-28 08:51:09  00:41:18
# 2        guest 2020-09-28 07:54:05  00:57:03
# 3        guest 2020-09-26 18:16:04  00:03:18
# 4        guest 2020-09-26 17:20:56  00:18:46
#
#                                     Attributes                        Title  \
# 0  Autoplayed: user action: User_Interaction;   자객 오육칠: 시즌 1: 부자가 되는 법 (1화)
# 1              Autoplayed: user action: None;      슬기로운 의사생활: 시즌 1: 5화 (5화)
# 2                                          NaN     슬기로운 의사생활: 시즌 1: 4화 (4화)
# 3                                          NaN     슬기로운 의사생활: 시즌 1: 4화 (4화)
# 4              Autoplayed: user action: None;      슬기로운 의사생활: 시즌 1: 4화 (4화)
#
#   Supplemental Video Type           Device Type  Bookmark  Latest Bookmark  \
# 0                     NaN  Safari MAC (Cadmium)  00:01:54         00:01:54
# 1                     NaN  Safari MAC (Cadmium)  00:41:28         00:41:28
# 2                     NaN  Safari MAC (Cadmium)  01:19:17         01:19:17
# 3                     NaN  Safari MAC (Cadmium)  00:22:15  Not latest view
# 4                     NaN  Safari MAC (Cadmium)  00:18:56  Not latest view
#
#                    Country  ...  Day  Day_name  Hour Minute  Second  \
# 0  KR (Korea, Republic of)  ...   30    Sunday    14      6       8
# 1  KR (Korea, Republic of)  ...   28    Monday     8     51       9
# 2  KR (Korea, Republic of)  ...   28    Monday     7     54       5
# 3  KR (Korea, Republic of)  ...   26  Saturday    18     16       4
# 4  KR (Korea, Republic of)  ...   26  Saturday    17     20      56
#
#    Duration_hour  Duration_min Duration_sec Duration_sec_sum      title
# 0             00            01           54              114     자객 오육칠
# 1             00            41           18             2478  슬기로운 의사생활
# 2             00            57           03             3423  슬기로운 의사생활
# 3             00            03           18              198  슬기로운 의사생활
# 4             00            18           46             1126  슬기로운 의사생활
#
# [5 rows x 22 columns]

# %%
len(total_Drama)
# Out:
# 13221

# %% [markdown]
# ## 같은 title의 duration 총합 구하기

# %%
total_Drama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13221 entries, 0 to 13220
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Profile Name             13221 non-null  object
#  1   Start Time               13221 non-null  datetime64[ns]
#  2   Duration                 13221 non-null  object
#  3   Attributes               4779 non-null   object
#  4   Title                    13221 non-null  object
#  5   Supplemental Video Type  0 non-null      object
#  6   Device Type              13221 non-null  object
#  7   Bookmark                 13221 non-null  object
#  8   Latest Bookmark          13221 non-null  object
#  9   Country                  13221 non-null  object
#  10  Year                     13221 non-null  int64
#  11  Month                    13221 non-null  int64
#  12  Day                      13221 non-null  int64
#  13  Day_name                 13221 non-null  object
#  14  Hour                     13221 non-null  int64
#  15  Minute                   13221 non-null  int64
#  16  Second                   13221 non-null  int64
#  17  Duration_hour            13221 non-null  object
#  18  Duration_min             13221 non-null  object
#  19  Duration_sec             13221 non-null  object
#  20  Duration_sec_sum         13221 non-null  int64
#  21  title                    13221 non-null  object
#  22  total_duration_sec       13221 non-null  object
# dtypes: datetime64[ns](1), int64(7), object(15)
# memory usage: 2.3+ MB

# %%
total_Drama["Duration_hour"] = total_Drama["Duration_hour"].astype(int)
total_Drama["Duration_min"] = total_Drama["Duration_min"].astype(int)
total_Drama["Duration_sec"] = total_Drama["Duration_sec"].astype(int)

# %%
total_Drama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13221 entries, 0 to 13220
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Profile Name             13221 non-null  object
#  1   Start Time               13221 non-null  datetime64[ns]
#  2   Duration                 13221 non-null  object
#  3   Attributes               4779 non-null   object
#  4   Title                    13221 non-null  object
#  5   Supplemental Video Type  0 non-null      object
#  6   Device Type              13221 non-null  object
#  7   Bookmark                 13221 non-null  object
#  8   Latest Bookmark          13221 non-null  object
#  9   Country                  13221 non-null  object
#  10  Year                     13221 non-null  int64
#  11  Month                    13221 non-null  int64
#  12  Day                      13221 non-null  int64
#  13  Day_name                 13221 non-null  object
#  14  Hour                     13221 non-null  int64
#  15  Minute                   13221 non-null  int64
#  16  Second                   13221 non-null  int64
#  17  Duration_hour            13221 non-null  int64
#  18  Duration_min             13221 non-null  int64
#  19  Duration_sec             13221 non-null  int64
#  20  Duration_sec_sum         13221 non-null  int64
#  21  title                    13221 non-null  object
#  22  total_duration_sec       13221 non-null  object
# dtypes: datetime64[ns](1), int64(10), object(12)
# memory usage: 2.3+ MB

# %%
total_Drama["total_duration_sec"] = total_Drama["Duration_hour"]*3600 + total_Drama["Duration_min"]*60 + total_Drama["Duration_sec"]
total_Drama.head()
# Out:
#   Profile Name          Start Time  Duration  \
# 0        guest 2021-05-30 14:06:08  00:01:54
# 1        guest 2020-09-28 08:51:09  00:41:18
# 2        guest 2020-09-28 07:54:05  00:57:03
# 3        guest 2020-09-26 18:16:04  00:03:18
# 4        guest 2020-09-26 17:20:56  00:18:46
#
#                                     Attributes                        Title  \
# 0  Autoplayed: user action: User_Interaction;   자객 오육칠: 시즌 1: 부자가 되는 법 (1화)
# 1              Autoplayed: user action: None;      슬기로운 의사생활: 시즌 1: 5화 (5화)
# 2                                          NaN     슬기로운 의사생활: 시즌 1: 4화 (4화)
# 3                                          NaN     슬기로운 의사생활: 시즌 1: 4화 (4화)
# 4              Autoplayed: user action: None;      슬기로운 의사생활: 시즌 1: 4화 (4화)
#
#   Supplemental Video Type           Device Type  Bookmark  Latest Bookmark  \
# 0                     NaN  Safari MAC (Cadmium)  00:01:54         00:01:54
# 1                     NaN  Safari MAC (Cadmium)  00:41:28         00:41:28
# 2                     NaN  Safari MAC (Cadmium)  01:19:17         01:19:17
# 3                     NaN  Safari MAC (Cadmium)  00:22:15  Not latest view
# 4                     NaN  Safari MAC (Cadmium)  00:18:56  Not latest view
#
#                    Country  ...  Day_name  Hour  Minute Second  Duration_hour  \
# 0  KR (Korea, Republic of)  ...    Sunday    14       6      8              0
# 1  KR (Korea, Republic of)  ...    Monday     8      51      9              0
# 2  KR (Korea, Republic of)  ...    Monday     7      54      5              0
# 3  KR (Korea, Republic of)  ...  Saturday    18      16      4              0
# 4  KR (Korea, Republic of)  ...  Saturday    17      20     56              0
#
#    Duration_min  Duration_sec  Duration_sec_sum      title  total_duration_sec
# 0             1            54               114     자객 오육칠                 114
# 1            41            18              2478  슬기로운 의사생활                2478
# 2            57             3              3423  슬기로운 의사생활                3423
# 3             3            18               198  슬기로운 의사생활                 198
# 4            18            46              1126  슬기로운 의사생활                1126
#
# [5 rows x 23 columns]

# %%
group = total_Drama.groupby(total_Drama["title"])
group.size()
# Out:
# title
# #캣츠                      1
# 100만 엔의 여인들             16
# 100인, 인간을 말하다            8
# 10대 사건으로 보는 제2차 세계대전    10
# 3D 그녀 리얼걸                1
#                         ..
# 희생자 게임                   1
# 히든싱어                     4
# 히스토리 101                 3
# 힐다                      23
# 힘쎈 여자 도봉순                6
# Length: 742, dtype: int64

# %%
group_duration_sec_sum = group["total_duration_sec"].sum()
group_duration_sec_sum = pd.DataFrame(group_duration_sec_sum, columns = ["total_duration_sec"])
group_duration_sec_sum
# Out:
#                       total_duration_sec
# title
# #캣츠                                 2818
# 100만 엔의 여인들                        10196
# 100인, 인간을 말하다                       4651
# 10대 사건으로 보는 제2차 세계대전                4229
# 3D 그녀 리얼걸                             15
# ...                                  ...
# 희생자 게임                                 7
# 히든싱어                                6948
# 히스토리 101                              10
# 힐다                                 21781
# 힘쎈 여자 도봉순                           6655
#
# [742 rows x 1 columns]

# %%
group_duration_sec_sum = group_duration_sec_sum.reset_index().rename(columns={"title": "title"})
group_duration_sec_sum
# Out:
#                     title  total_duration_sec
# 0                     #캣츠                2818
# 1             100만 엔의 여인들               10196
# 2           100인, 인간을 말하다                4651
# 3    10대 사건으로 보는 제2차 세계대전                4229
# 4               3D 그녀 리얼걸                  15
# ..                    ...                 ...
# 737                희생자 게임                   7
# 738                  히든싱어                6948
# 739              히스토리 101                  10
# 740                    힐다               21781
# 741             힘쎈 여자 도봉순                6655
#
# [742 rows x 2 columns]

# %% [markdown]
# ## Top 5 추출
#
# 정렬후 추출하는 방식

# %%
order = group_duration_sec_sum.sort_values(by="total_duration_sec", ascending=False)
order = order.reset_index(drop=True)
order
# Out:
#                    title  total_duration_sec
# 0                  빅뱅 이론             3189397
# 1           내가 그녀를 만났을 때              331583
# 2              슬기로운 의사생활              316420
# 3                    루시퍼              278169
# 4             그레이스 앤 프랭키              266626
# ..                   ...                 ...
# 737               마성의 기쁨                   1
# 738  TV유치원 - 바쁘다 바빠 직업탐험                   1
# 739      일라이자 슐레싱거의 쇼타임!                   1
# 740       닥터 샌더스의 위대한 진단                   1
# 741            늑대소녀와 흑왕자                   1
#
# [742 rows x 2 columns]

# %%
top5 = order.iloc[:5]
top5["total_duration_min"] = round(top5["total_duration_sec"]/60, 2)
top5["total_duration_hour"] = round(top5["total_duration_sec"]/3600, 2)
top5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           title  total_duration_sec  total_duration_min  total_duration_hour
# 0         빅뱅 이론             3189397            53156.62               885.94
# 1  내가 그녀를 만났을 때              331583             5526.38                92.11
# 2     슬기로운 의사생활              316420             5273.67                87.89
# 3           루시퍼              278169             4636.15                77.27
# 4    그레이스 앤 프랭키              266626             4443.77                74.06

# %% [markdown]
# ## top5 시각화
#
# bar chart

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()
    # colab 사용자는 system_name이 'Linux'로 확인

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont
        
        font_family = "NanumBarunGothic"
    return font_family

# %%
# 위에서 만든 함수를 통해 시스템 폰트를 불러와서 font_family 라는 변수에 할당
font_family = get_font_family()
# 폰트설정
plt.rc("font", family=font_family)
# 마이너스폰트 설정
plt.rc("axes", unicode_minus=False)
# 그래프 스타일 설정
plt.style.use("ggplot")

# 그래프에 retina display 적용
from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")
# Out:
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# ### 초(시간단위)

# %%
plt.bar(top5["title"], top5["total_duration_sec"])
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=16)
plt.show()

# %% [markdown]
# ### 분(시간단위)

# %%
plt.bar(top5["title"], top5["total_duration_min"])
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=16)
plt.show()

# %% [markdown]
# ### 시(시간단위)

# %%
plt.bar(top5["title"], top5["total_duration_hour"])
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=16)
plt.show()

# %% [markdown]
# # 3. 많이 본 영화 장르 Top5(중복값 허용 &  중복값 제거)
# Radar chart

# %%
Netflix
# Out:
#       Profile Name          Start Time  Duration  \
# 0            guest 2021-05-31 02:25:20  00:00:05
# 1            guest 2021-05-30 14:08:38  00:00:04
# 2            guest 2021-05-30 14:08:20  00:00:04
# 3            guest 2021-05-30 14:06:08  00:01:54
# 4            guest 2021-05-30 14:05:48  00:00:17
# ...            ...                 ...       ...
# 19156          김지은 2019-02-09 04:25:19  00:00:23
# 19157          김지은 2019-02-09 04:20:35  00:00:57
# 19158          김지은 2019-02-09 04:08:47  00:00:18
# 19159          김지은 2019-02-09 03:10:57  00:00:11
# 19160          김지은 2019-02-09 03:10:37  00:00:06
#
#                                         Attributes  \
# 0                  Autoplayed: user action: None;
# 1      Autoplayed: user action: User_Interaction;
# 2                  Autoplayed: user action: None;
# 3      Autoplayed: user action: User_Interaction;
# 4                  Autoplayed: user action: None;
# ...                                            ...
# 19156                                          NaN
# 19157                                          NaN
# 19158                                          NaN
# 19159                                          NaN
# 19160                                          NaN
#
#                                           Title Supplemental Video Type  \
# 0             Move to Heaven: Season 1 (Hook 1)                    HOOK
# 1                                     가질 수 없는 너                     NaN
# 2      Gatao - The Last Stray_hook_primary_16x9                    HOOK
# 3                   자객 오육칠: 시즌 1: 부자가 되는 법 (1화)                     NaN
# 4                            시즌 2 (예고편): 자객 오육칠                 TRAILER
# ...                                         ...                     ...
# 19156               릭 앤 모티: 시즌 1: 파일럿 에피소드 (1화)                     NaN
# 19157                오티스의 비밀 상담소: 시즌 1: 1화 (1화)                     NaN
# 19158                         킹덤: 시즌 1: 1화 (1화)                     NaN
# 19159                         킹덤: 시즌 1: 1화 (1화)                     NaN
# 19160                         킹덤: 시즌 1: 1화 (1화)                     NaN
#
#                                Device Type  Bookmark  Latest Bookmark  \
# 0      Netflix Chrome MAC (Cadmium) HTML 5  00:00:05         00:00:05
# 1                     Safari MAC (Cadmium)  00:00:04         00:00:04
# 2                     Safari MAC (Cadmium)  00:00:04         00:00:04
# 3                     Safari MAC (Cadmium)  00:01:54         00:01:54
# 4                     Safari MAC (Cadmium)  00:00:17         00:00:17
# ...                                    ...       ...              ...
# 19156       Netflix Android STB L3 Android  00:00:23  Not latest view
# 19157       Netflix Android STB L3 Android  00:00:57  Not latest view
# 19158       Netflix Android STB L3 Android  00:00:23         00:00:23
# 19159                 Apple iPhone X (GSM)  00:00:11  Not latest view
# 19160                 Apple iPhone X (GSM)  00:00:06  Not latest view
#
#                        Country  ...  Month  Day  Day_name Hour  Minute  \
# 0      KR (Korea, Republic of)  ...      5   31    Monday    2      25
# 1      KR (Korea, Republic of)  ...      5   30    Sunday   14       8
# 2      KR (Korea, Republic of)  ...      5   30    Sunday   14       8
# 3      KR (Korea, Republic of)  ...      5   30    Sunday   14       6
# 4      KR (Korea, Republic of)  ...      5   30    Sunday   14       5
# ...                        ...  ...    ...  ...       ...  ...     ...
# 19156  KR (Korea, Republic of)  ...      2    9  Saturday    4      25
# 19157  KR (Korea, Republic of)  ...      2    9  Saturday    4      20
# 19158  KR (Korea, Republic of)  ...      2    9  Saturday    4       8
# 19159  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
# 19160  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
#
#        Second  Duration_hour Duration_min Duration_sec Duration_sec_sum
# 0          20             00           00           05                5
# 1          38             00           00           04                4
# 2          20             00           00           04                4
# 3           8             00           01           54              114
# 4          48             00           00           17               17
# ...       ...            ...          ...          ...              ...
# 19156      19             00           00           23               23
# 19157      35             00           00           57               57
# 19158      47             00           00           18               18
# 19159      57             00           00           11               11
# 19160      37             00           00           06                6
#
# [19161 rows x 21 columns]

# %% [markdown]
# ## 예고편 제거

# %%
Netflix["Supplemental Video Type"].unique()
# Out:
# array(['HOOK', nan, 'TRAILER', 'TEASER_TRAILER', 'PREVIEW', 'RECAP',
#        'CINEMAGRAPH', 'PROMOTIONAL', 'TUTORIAL', 'TAKE_OVER'],
#       dtype=object)

# %%
no_trailer = Netflix[Netflix["Supplemental Video Type"].isnull()]
no_trailer = no_trailer.reset_index(drop=True)
no_trailer
# Out:
#       Profile Name          Start Time  Duration  \
# 0            guest 2021-05-30 14:08:38  00:00:04
# 1            guest 2021-05-30 14:06:08  00:01:54
# 2            guest 2021-05-30 12:46:21  00:47:35
# 3            guest 2021-05-30 11:25:03  00:26:49
# 4            guest 2020-09-28 08:51:09  00:41:18
# ...            ...                 ...       ...
# 15346          김지은 2019-02-09 04:25:19  00:00:23
# 15347          김지은 2019-02-09 04:20:35  00:00:57
# 15348          김지은 2019-02-09 04:08:47  00:00:18
# 15349          김지은 2019-02-09 03:10:57  00:00:11
# 15350          김지은 2019-02-09 03:10:37  00:00:06
#
#                                         Attributes  \
# 0      Autoplayed: user action: User_Interaction;
# 1      Autoplayed: user action: User_Interaction;
# 2                                              NaN
# 3                                              NaN
# 4                  Autoplayed: user action: None;
# ...                                            ...
# 15346                                          NaN
# 15347                                          NaN
# 15348                                          NaN
# 15349                                          NaN
# 15350                                          NaN
#
#                              Title Supplemental Video Type  \
# 0                        가질 수 없는 너                     NaN
# 1      자객 오육칠: 시즌 1: 부자가 되는 법 (1화)                     NaN
# 2                         라플라스의 마녀                     NaN
# 3                         라플라스의 마녀                     NaN
# 4         슬기로운 의사생활: 시즌 1: 5화 (5화)                     NaN
# ...                            ...                     ...
# 15346  릭 앤 모티: 시즌 1: 파일럿 에피소드 (1화)                     NaN
# 15347   오티스의 비밀 상담소: 시즌 1: 1화 (1화)                     NaN
# 15348            킹덤: 시즌 1: 1화 (1화)                     NaN
# 15349            킹덤: 시즌 1: 1화 (1화)                     NaN
# 15350            킹덤: 시즌 1: 1화 (1화)                     NaN
#
#                           Device Type  Bookmark  Latest Bookmark  \
# 0                Safari MAC (Cadmium)  00:00:04         00:00:04
# 1                Safari MAC (Cadmium)  00:01:54         00:01:54
# 2                Safari MAC (Cadmium)  01:10:36         01:10:36
# 3                Safari MAC (Cadmium)  00:26:49  Not latest view
# 4                Safari MAC (Cadmium)  00:41:28         00:41:28
# ...                               ...       ...              ...
# 15346  Netflix Android STB L3 Android  00:00:23  Not latest view
# 15347  Netflix Android STB L3 Android  00:00:57  Not latest view
# 15348  Netflix Android STB L3 Android  00:00:23         00:00:23
# 15349            Apple iPhone X (GSM)  00:00:11  Not latest view
# 15350            Apple iPhone X (GSM)  00:00:06  Not latest view
#
#                        Country  ...  Month  Day  Day_name Hour  Minute  \
# 0      KR (Korea, Republic of)  ...      5   30    Sunday   14       8
# 1      KR (Korea, Republic of)  ...      5   30    Sunday   14       6
# 2      KR (Korea, Republic of)  ...      5   30    Sunday   12      46
# 3      KR (Korea, Republic of)  ...      5   30    Sunday   11      25
# 4      KR (Korea, Republic of)  ...      9   28    Monday    8      51
# ...                        ...  ...    ...  ...       ...  ...     ...
# 15346  KR (Korea, Republic of)  ...      2    9  Saturday    4      25
# 15347  KR (Korea, Republic of)  ...      2    9  Saturday    4      20
# 15348  KR (Korea, Republic of)  ...      2    9  Saturday    4       8
# 15349  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
# 15350  KR (Korea, Republic of)  ...      2    9  Saturday    3      10
#
#        Second  Duration_hour Duration_min Duration_sec Duration_sec_sum
# 0          38             00           00           04                4
# 1           8             00           01           54              114
# 2          21             00           47           35             2855
# 3           3             00           26           49             1609
# 4           9             00           41           18             2478
# ...       ...            ...          ...          ...              ...
# 15346      19             00           00           23               23
# 15347      35             00           00           57               57
# 15348      47             00           00           18               18
# 15349      57             00           00           11               11
# 15350      37             00           00           06                6
#
# [15351 rows x 21 columns]

# %%
Movies= no_trailer.loc[~no_trailer["Title"].str.contains(": ")]
Movies = Movies .reset_index(drop=True)
Movies
# Out:
#      Profile Name          Start Time  Duration  \
# 0           guest 2021-05-30 14:08:38  00:00:04
# 1           guest 2021-05-30 12:46:21  00:47:35
# 2           guest 2021-05-30 11:25:03  00:26:49
# 3           guest 2020-09-25 15:32:39  00:24:28
# 4           guest 2020-09-25 14:27:15  01:00:15
# ...           ...                 ...       ...
# 2128          김지은 2019-05-26 19:59:01  00:04:05
# 2129          김지은 2019-05-01 20:29:37  00:30:51
# 2130          김지은 2019-05-01 11:08:43  01:43:47
# 2131          김지은 2019-04-16 21:46:05  00:00:07
# 2132          김지은 2019-04-16 15:29:12  00:23:47
#
#                                        Attributes       Title  \
# 0     Autoplayed: user action: User_Interaction;    가질 수 없는 너
# 1                                             NaN    라플라스의 마녀
# 2                                             NaN    라플라스의 마녀
# 3          Autoplayed: user action: Unspecified;      키싱 부스 2
# 4                                             NaN       키싱 부스
# ...                                           ...         ...
# 2128       Autoplayed: user action: Unspecified;   창의적인 뇌의 비밀
# 2129       Autoplayed: user action: Unspecified;    섹스 앤 더 시티
# 2130       Autoplayed: user action: Unspecified;     닥터 스트레인지
# 2131       Autoplayed: user action: Unspecified;   첫 경험 훼방 작전
# 2132       Autoplayed: user action: Unspecified;      어쩌다 로맨스
#
#      Supplemental Video Type           Device Type  Bookmark  Latest Bookmark  \
# 0                        NaN  Safari MAC (Cadmium)  00:00:04         00:00:04
# 1                        NaN  Safari MAC (Cadmium)  01:10:36         01:10:36
# 2                        NaN  Safari MAC (Cadmium)  00:26:49  Not latest view
# 3                        NaN  Safari MAC (Cadmium)  00:24:28         00:24:28
# 4                        NaN  Safari MAC (Cadmium)  01:43:46         01:43:46
# ...                      ...                   ...       ...              ...
# 2128                     NaN  Safari MAC (Cadmium)  00:07:32  Not latest view
# 2129                     NaN  Safari MAC (Cadmium)  00:30:28  Not latest view
# 2130                     NaN  Safari MAC (Cadmium)  01:44:57         01:44:57
# 2131                     NaN  Safari MAC (Cadmium)  00:04:49         00:04:49
# 2132                     NaN  Safari MAC (Cadmium)  01:24:03         01:24:03
#
#                       Country  ...  Month  Day   Day_name Hour  Minute  \
# 0     KR (Korea, Republic of)  ...      5   30     Sunday   14       8
# 1     KR (Korea, Republic of)  ...      5   30     Sunday   12      46
# 2     KR (Korea, Republic of)  ...      5   30     Sunday   11      25
# 3     KR (Korea, Republic of)  ...      9   25     Friday   15      32
# 4     KR (Korea, Republic of)  ...      9   25     Friday   14      27
# ...                       ...  ...    ...  ...        ...  ...     ...
# 2128  KR (Korea, Republic of)  ...      5   26     Sunday   19      59
# 2129  KR (Korea, Republic of)  ...      5    1  Wednesday   20      29
# 2130  KR (Korea, Republic of)  ...      5    1  Wednesday   11       8
# 2131  KR (Korea, Republic of)  ...      4   16    Tuesday   21      46
# 2132  KR (Korea, Republic of)  ...      4   16    Tuesday   15      29
#
#       Second  Duration_hour Duration_min Duration_sec Duration_sec_sum
# 0         38             00           00           04                4
# 1         21             00           47           35             2855
# 2          3             00           26           49             1609
# 3         39             00           24           28             1468
# 4         15             01           00           15               75
# ...      ...            ...          ...          ...              ...
# 2128       1             00           04           05              245
# 2129      37             00           30           51             1851
# 2130      43             01           43           47             2687
# 2131       5             00           00           07                7
# 2132      12             00           23           47             1427
#
# [2133 rows x 21 columns]

# %%
Title_list = list(Movies["Title"])
Title_list
# Out:
# ['가질 수 없는 너',
#  '라플라스의 마녀',
#  '라플라스의 마녀',
#  '키싱 부스 2',
#  '키싱 부스',
#  '키싱 부스',
#  '키싱 부스 2',
#  '키싱 부스 2',
#  '키싱 부스 2',
#  '키싱 부스 2',
#  '키싱 부스 2',
#  '키싱 부스 2',
#  '청설',
#  '내가 사랑했던 모든 남자들에게',
#  '키싱 부스',
#  '내가 사랑했던 모든 남자들에게',
#  '내가 사랑했던 모든 남자들에게',
#  '사랑할 때 버려야 할 아까운 것들',
#  '프린세스 다이어리 2',
#  '프린세스 다이어리 2',
#  '프린세스 다이어리 2',
#  '내가 사랑했던 모든 남자들에게',
#  '내가 사랑했던 모든 남자들에게',
#  '내가 사랑했던 모든 남자들에게',
#  '내가 사랑했던 모든 남자들에게',
#  '내가 사랑했던 모든 남자들에게',
#  '내가 사랑했던 모든 남자들에게',
#  '라푼젤',
#  '프린세스 다이어리',
#  '내가 사랑했던 모든 남자들에게',
#  '키싱 부스',
#  '키싱 부스',
#  '키싱 부스',
#  '시에라 연애 대작전',
#  '시에라 연애 대작전',
#  '스텝 시스터스',
#  '썸원 그레이트',
#  '아메리칸 사이코',
#  '도둑맞은 그 5년',
#  '도둑맞은 그 5년',
#  '도둑맞은 그 5년',
#  '내가 사랑했던 모든 남자들에게',
#  '내가 사랑했던 모든 남자들에게',
#  '아메리칸 사이코',
#  '도둑맞은 그 5년',
#  '도둑맞은 그 5년',
#  '도둑맞은 그 5년',
#  '도둑맞은 그 5년',
#  '도둑맞은 그 5년',
#  '카페 소사이어티',
#  '카페 소사이어티',
#  '빅쇼트',
#  '하우 투 비 싱글',
#  '아이리시맨',
#  '아이리시맨',
#  '아이리시맨',
#  '아이리시맨',
#  '크리스마스에 기사가 올까요?',
#  '아이리시맨을 말하다',
#  '크리스마스에 기사가 올까요?',
#  '터미널',
#  '결혼 이야기',
#  '결혼 이야기',
#  '내가 사랑했던 모든 남자들에게',
#  '배틀',
#  '내가 사랑했던 모든 남자들에게',
#  '슬리핑 위드 아더 피플',
#  '상사에 대처하는 로맨틱한 자세',
#  '상사에 대처하는 로맨틱한 자세',
#  '크리스마스에 기사가 올까요?',
#  '크리스마스에 기사가 올까요?',
#  '겨울왕국',
#  '미드나잇 인 파리',
#  '미드나잇 인 파리',
#  '인셉션',
#  '미드나잇 인 파리',
#  '미드나잇 인 파리',
#  '미드나잇 인 파리',
#  '퀸카가 아니어도 좋아',
#  '퀸카가 아니어도 좋아',
#  '내가 사랑했던 모든 남자들에게',
#  '내가 사랑했던 모든 남자들에게',
#  '키싱 부스',
#  '빅 피쉬',
#  '더 이퀄라이저',
#  '다운사이징',
#  '썸원 그레이트',
#  '어쩌다 로맨스',
#  '나를 차버린 스파이',
#  '마약왕',
#  '마약왕',
#  '마약왕',
#  '셜록 홈즈',
#  '셜록 홈즈',
#  '셜록 홈즈',
#  'Limitless',
#  'Limitless',
#  'Limitless',
#  '벚꽃 같은 나의 연인',
#  '모리의 정원',
#  '해피 해피 레스토랑',
#  '해피 해피 레스토랑',
#  '해피 해피 레스토랑',
#  '어디갔어, 버나뎃',
#  '모리의 정원',
#  '레드슈즈',
#  '461개의 도시락',
#  '모리의 정원',
#  '모리의 정원',
#  '에놀라 홈즈',
#  '에놀라 홈즈',
#  '우리는 모두 어른이 될 수 없었다',
#  '어디갔어, 버나뎃',
#  '애틀랜틱스',
#  '니노쿠니',
#  '빅토리아 & 압둘',
#  '빅토리아 & 압둘',
#  '레전드',
#  '대니쉬 걸',
#  '더 디그',
#  '코쿠리코 언덕에서',
#  '심야식당 2',
#  '추억은 방울방울',
#  '추억은 방울방울',
#  '고양이를 빌려드립니다',
#  '고양이를 빌려드립니다',
#  '클로버',
#  '추억은 방울방울',
#  '귀를 기울이면',
#  '고양이를 빌려드립니다',
#  '행복 목욕탕',
#  '마루 밑 아리에티',
#  '핫 걸 원티드',
#  '로코',
#  '펜트하우스 코끼리',
#  '졸업반',
#  '유혹',
#  '마루 밑 아리에티',
#  '마루 밑 아리에티',
#  '귀를 기울이면',
#  '이웃집 야마다 군',
#  '이웃집 야마다 군',
#  '펭귄 하이웨이',
#  '귀를 기울이면',
#  '귀를 기울이면',
#  '귀를 기울이면',
#  '귀를 기울이면',
#  '귀를 기울이면',
#  '귀를 기울이면',
#  '코쿠리코 언덕에서',
#  '고양이를 빌려드립니다',
#  '고양이를 빌려드립니다',
#  '고양이를 빌려드립니다',
#  '고양이를 빌려드립니다',
#  '고양이를 빌려드립니다',
#  '카모메 식당',
#  '거북이는 의외로 빨리 헤엄친다',
#  '카모메 식당',
#  '카모메 식당',
#  '카모메 식당',
#  '카모메 식당',
#  '카모메 식당',
#  '아이',
#  '심야식당 2',
#  '아버지와 이토 씨',
#  '카모메 식당',
#  '고양이를 빌려드립니다',
#  '고양이를 빌려드립니다',
#  '모노노케 히메',
#  '나이브스 아웃',
#  '도쿄타워',
#  '등산의 목적',
#  '졸업반',
#  '호문쿨루스',
#  '호문쿨루스',
#  '호문쿨루스',
#  '호문쿨루스',
#  '카모메 식당',
#  '해변의 에트랑제',
#  '이 세상의 한구석에',
#  '고양이를 빌려드립니다',
#  '도쿄연애사건',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  'NullCompleteVideo',
#  '승리호',
#  '벼랑 위의 포뇨',
#  '벼랑 위의 포뇨',
#  '벼랑 위의 포뇨',
#  '벼랑 위의 포뇨',
#  '벼랑 위의 포뇨',
#  '벼랑 위의 포뇨',
#  '바람계곡의 나우시카',
#  '벼랑 위의 포뇨',
#  '하울의 움직이는 성',
#  '벼랑 위의 포뇨',
#  '붉은 바캉스 검은 웨딩',
#  '유혹',
#  '시험에 들지 말게 하옵시며',
#  '후궁：제왕의 첩',
#  '후궁：제왕의 첩',
#  '상류사회',
#  '아가씨',
#  '라플라스의 마녀',
#  '마더',
#  '미결처리반 Q',
#  '파라메딕 앙헬',
#  '드라이 마르티나',
#  '뉴니스',
#  '돈의 맛',
#  '투마더스',
#  '프렌치 더티',
#  '미교소녀',
#  '렌즈',
#  '가위바위보',
#  '도마 위의 정사',
#  '사랑 없는 숲',
#  '상류사회',
#  '가루지기',
#  '후궁：제왕의 첩',
#  '간신',
#  '도쿄연애사건',
#  '레이디 맥베스',
#  '네가 없는 시간',
#  '스텔라를 납치했다',
#  '파라메딕 앙헬',
#  '레베카',
#  '증인',
#  '레베카',
#  '셜록 홈즈',
#  '캐치 미 이프 유 캔',
#  '추억의 마니',
#  '레이디 맥베스',
#  '뉴니스',
#  '화차',
#  '두근두근, 도쿄!',
#  '365일',
#  '후궁：제왕의 첩',
#  '오, 라모나!',
#  '졸업반',
#  '365일',
#  '화이트 걸',
#  '365일',
#  '올 이즈 굿',
#  '이지 걸',
#  '엘리사와 마르셀라',
#  '지진새',
#  '뉴니스',
#  '365일',
#  '센과 치히로의 행방불명',
#  '센과 치히로의 행방불명',
#  '센과 치히로의 행방불명',
#  '센과 치히로의 행방불명',
#  '증인',
#  '도쿄연애사건',
#  '아버지와 이토 씨',
#  '82년생 김지영',
#  '심야식당 2',
#  '센과 치히로의 행방불명',
#  '인셉션',
#  '울고 싶은 나는 고양이 가면을 쓴다',
#  '졸업반',
#  '365일',
#  '심야식당 (극장판)',
#  '가슴 배구단',
#  '사랑 없는 숲',
#  '하울의 움직이는 성',
#  '하울의 움직이는 성',
#  '하울의 움직이는 성',
#  '하울의 움직이는 성',
#  '하울의 움직이는 성',
#  '원더풀 라이프',
#  '고양이의 보은',
#  '고양이의 보은',
#  '마루 밑 아리에티',
#  '마녀 배달부 키키',
#  'To All The Boys I’ve Loved Before_shortpreview_9x16',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '내 몸이 사라졌다',
#  '마녀 배달부 키키',
#  '결혼 이야기',
#  '내가 사랑했던 모든 남자들에게',
#  '秘書 ～黒蠍の誘惑～',
#  '행복한  남자',
#  '행복한  남자',
#  '더 버블',
#  '블랙 크랩',
#  '해피엔드',
#  '오! 수정',
#  '해피엔드',
#  '해피엔드',
#  '블랙 크랩',
#  '해피엔드',
#  '색, 계',
#  '애덤 프로젝트',
#  '애덤 프로젝트',
#  '블랙 크랩',
#  '아무것도 잃을 것은 없다',
#  '오페라의 유령',
#  '레미제라블',
#  '등산의 목적',
#  '방자전',
#  '바람난가족',
#  '색, 계',
#  '드림셀러',
#  '드림셀러',
#  '인간중독',
#  '바람난가족',
#  '붉은 바캉스 검은 웨딩',
#  '후궁：제왕의 첩',
#  '밀애',
#  '붉은 바캉스 검은 웨딩',
#  '아가씨',
#  '예수는역사다',
#  '예수는역사다',
#  '패밀리 맨',
#  '인터뷰',
#  '데몰리션',
#  '데몰리션',
#  '해피엔드',
#  '얼어버린 시간 속에서',
#  '얼어버린 시간 속에서',
#  '해피엔드',
#  '블루 미라클',
#  '혹시 내게 무슨 일이 생기면',
#  '오두막',
#  '조지아의 상인',
#  '로마서 8:37',
#  '시크릿',
#  '미라클 프롬 헤븐',
#  '드림셀러',
#  '사일런스',
#  '메카닉',
#  '메카닉',
#  '#아이엠히어',
#  '#아이엠히어',
#  '초미의 관심사',
#  '해피엔드',
#  '콜드 마운틴',
#  '모럴센스',
#  '벤전스',
#  '힘을 내요, 미스터 리',
#  '힘을 내요, 미스터 리',
#  '힘을 내요, 미스터 리',
#  '힘을 내요, 미스터 리',
#  '모럴센스',
#  '메기',
#  '메기',
#  '메기',
#  '가장 보통의 연애',
#  '머니백',
#  '장르만 로맨스',
#  '장르만 로맨스',
#  '파워 오브 도그',
#  '파워 오브 도그',
#  '해피엔드',
#  '장르만 로맨스',
#  '빅버그',
#  '빅버그',
#  '빅버그',
#  '배리',
#  '빅버그',
#  '배리',
#  '하늘을 걷는 남자',
#  '모럴센스',
#  '모럴센스',
#  '등산의 목적',
#  '순수의 시대',
#  '스노우화이트',
#  '1917',
#  '몽상가들',
#  '방자전',
#  '여교수의 은밀한 매력',
#  '나랏말싸미',
#  '시간 여행자의 아내',
#  '해피엔드',
#  '해피엔드',
#  '워킹걸',
#  '워킹걸',
#  '럭키',
#  '인 타임',
#  '해피엔드',
#  '해피엔드',
#  '예수는역사다',
#  '범죄의 재구성',
#  '범죄의 재구성',
#  '범죄의 재구성',
#  '마더/안드로이드',
#  '인사이드 맨',
#  '인사이드 맨',
#  '마담 뺑덕',
#  '행복한  남자',
#  '마더/안드로이드',
#  '매트릭스 3 레볼루션',
#  '매트릭스',
#  '매트릭스 3 레볼루션',
#  '매트릭스',
#  '바이스',
#  '동네사람들',
#  '동네사람들',
#  '동네사람들',
#  '아멜리에',
#  '가문의영광5 - 가문의 귀환',
#  '히트맨',
#  '해치지않아',
#  '비열한 거리',
#  '시간이탈자',
#  '봉이 김선달',
#  '13층',
#  '꾼',
#  '결혼전야',
#  '귀문',
#  '미드나잇 인 파리',
#  '노예 12년',
#  '리플리',
#  '킬링소프틀리',
#  '레전드',
#  '워 머신',
#  '포커스',
#  '조 블랙의 사랑',
#  '포커스',
#  '어카운턴트',
#  '가을의 전설',
#  '레드 노티스',
#  '스파이더맨 3',
#  '돈 룩 업',
#  '돈 룩 업',
#  '모가디슈',
#  '모가디슈',
#  '모가디슈',
#  '밀애',
#  '무뢰한',
#  '인간중독',
#  '인간중독',
#  '모가디슈',
#  '해피엔드',
#  '해피엔드',
#  '해피엔드',
#  '해피엔드',
#  '싱크홀',
#  '인질',
#  '싱크홀',
#  '바람난가족',
#  '밤의 해변에서 혼자',
#  '레미제라블',
#  '레미제라블',
#  '레미제라블',
#  '레미제라블',
#  '뷰티풀 마인드',
#  '뷰티풀 마인드',
#  '원스 어폰 어 타임 인... 할리우드',
#  '낙원의 밤',
#  '일본 침몰',
#  '일본 침몰',
#  '다키스트 아워',
#  '방자전',
#  '색, 계',
#  '기억의 밤',
#  '기억의 밤',
#  '기억의 밤',
#  '기억의 밤',
#  '기억의 밤',
#  '13층',
#  '13층',
#  '13층',
#  '13층',
#  '13층',
#  '13층',
#  '13층',
#  '예스맨',
#  '예스맨',
#  '아미 오브 더 데드',
#  '아가씨',
#  '후궁：제왕의 첩',
#  '리얼',
#  '아미 오브 더 데드',
#  '아미 오브 더 데드',
#  '더 하더 데이 폴',
#  '해피엔드',
#  '밤의 해변에서 혼자',
#  '그 후',
#  '아미 오브 더 데드',
#  '레드 노티스',
#  '바람난가족',
#  '해피엔드',
#  '해피엔드',
#  '해피엔드',
#  '여교수의 은밀한 매력',
#  '레드 노티스',
#  '레드 노티스',
#  '클래식',
#  '클래식',
#  '클래식',
#  '인간중독',
#  '여교수의 은밀한 매력',
#  '해피엔드',
#  '바람난가족',
#  '마담 뺑덕',
#  '마담 뺑덕',
#  '등산의 목적',
#  '지금 사랑하는 사람과 살고 있습니까?',
#  '바람난가족',
#  '바람난가족',
#  '바람난가족',
#  '아가씨',
#  '마담 뺑덕',
#  '해피엔드',
#  '해피엔드',
#  '바람난가족',
#  '지금 사랑하는 사람과 살고 있습니까?',
#  '지금 사랑하는 사람과 살고 있습니까?',
#  '케이트',
#  '블랙코드',
#  '블랙코드',
#  '바람난가족',
#  '해피엔드',
#  '마담 뺑덕',
#  '해피엔드',
#  '해피엔드',
#  '마담 뺑덕',
#  '마담 뺑덕',
#  '마담 뺑덕',
#  '해피엔드',
#  '해피엔드',
#  '후궁：제왕의 첩',
#  '연인',
#  '등산의 목적',
#  '방자전',
#  '방자전',
#  '방자전',
#  '밀애',
#  '환상의 버섯',
#  '환상의 버섯',
#  '바람의 검심',
#  '바람의 검심',
#  '방자전',
#  '등산의 목적',
#  '오! 수정',
#  '해피엔드',
#  '해피엔드',
#  '등산의 목적',
#  '등산의 목적',
#  '마담 뺑덕',
#  '등산의 목적',
#  '아가씨',
#  '타짜',
#  '타짜-신의손',
#  '타짜-신의손',
#  '타짜-신의손',
#  '시간이탈자',
#  '사라진 시간',
#  '사라진 시간',
#  '건 시티 바르셀로나',
#  '진주 귀걸이를 한 소녀',
#  '건 시티 바르셀로나',
#  '사라진 시간',
#  '밀애',
#  '해피엔드',
#  '오케이 마담',
#  '오케이 마담',
#  '실버 스케이트',
#  '건 시티 바르셀로나',
#  '등산의 목적',
#  '해피엔드',
#  '진주 귀걸이를 한 소녀',
#  '실버 스케이트',
#  '실버 스케이트',
#  '실버 스케이트',
#  '해피엔드',
#  '노블 인텐션',
#  '해피엔드',
#  '마담 뺑덕',
#  '마담 뺑덕',
#  '마담 뺑덕',
#  '바람 바람 바람',
#  '펜트하우스 코끼리',
#  '마담 뺑덕',
#  '유혹',
#  '밀애',
#  '아가씨',
#  '마담 뺑덕',
#  '해피엔드',
#  '무뢰한',
#  '해피엔드',
#  '마담 뺑덕',
#  '돈의 맛',
#  '마담 뺑덕',
#  '신의 한 수',
#  '신의 한 수',
#  '신의 한 수',
#  '신의 한 수',
#  '리얼',
#  '지푸라기라도 잡고 싶은 짐승들',
#  '아이',
#  '아이',
#  '아이',
#  'O2',
#  '마담 뺑덕',
#  '도마 위의 정사',
#  '해피엔드',
#  '해피엔드',
#  '아가씨',
#  '상류사회',
#  '해피엔드',
#  '해피엔드',
#  '화이트 타이거',
#  '화이트 타이거',
#  '화이트 타이거',
#  '범털',
#  '더 이글',
#  '더 이글',
#  '마담 뺑덕',
#  '아가씨',
#  '박쥐',
#  '미스 푸줏간',
#  '펜트하우스 코끼리',
#  '히든 피겨스',
#  '낙원의 밤',
#  '러브 앤 몬스터스',
#  '아가씨',
#  '아가씨',
#  '아가씨',
#  '원라인',
#  '아가씨',
#  '아가씨',
#  '아가씨',
#  '해피엔드',
#  '해피엔드',
#  '원라인',
#  '원라인',
#  '해피엔드',
#  '색, 계',
#  '과학, 지식 릴레이',
#  '문신을 한 신부님',
#  '뚜르:내 생애 최고의 49일',
#  '해피엔드',
#  '등산의 목적',
#  '해피엔드',
#  '해피엔드',
#  '상류사회',
#  '스파이 브릿지',
#  '해리엇',
#  '해리엇',
#  '해리엇',
#  '내사랑',
#  '내사랑',
#  '해리엇',
#  '늑대의 살갗 아래',
#  '아토믹 블론드',
#  '아토믹 블론드',
#  '뉴스 오브 더 월드',
#  '뉴스 오브 더 월드',
#  '에너미 앳 더 게이트',
#  '뉴스 오브 더 월드',
#  '밀애',
#  '붉은 바캉스 검은 웨딩',
#  '마담 뺑덕',
#  '사랑 없는 숲',
#  '도마 위의 정사',
#  '삼진그룹 영어토익반',
#  '스파이 브릿지',
#  '승리호',
#  '승리호',
#  '마담 뺑덕',
#  '더 서클',
#  '더 서클',
#  '더 서클',
#  '더 서클',
#  '헌트',
#  '더 디그',
#  '더 디그',
#  '더 디그',
#  '마담 뺑덕',
#  '더 게임 체인저스',
#  '더 게임 체인저스',
#  '더 게임 체인저스',
#  '해피엔드',
#  '아논',
#  '아웃사이드 더 와이어',
#  '아웃사이드 더 와이어',
#  '아웃사이드 더 와이어',
#  '아웃사이드 더 와이어',
#  '스파이 게임',
#  '스파이 게임',
#  '색, 계',
#  '그 후',
#  '밤의 해변에서 혼자',
#  '차인표',
#  '차인표',
#  '색, 계',
#  '안시성',
#  '하이 라이프',
#  '가타카',
#  '가타카',
#  '클로버필드 패러독스',
#  '클로버필드 패러독스',
#  '클로버필드 패러독스',
#  '러셀 크로우의 아이언 피스트',
#  '클로버필드 패러독스',
#  '나의 마더',
#  '나의 마더',
#  'IO',
#  'IO',
#  'IO',
#  '해피엔드',
#  '졸업반',
#  '무뢰한',
#  '6 언더그라운드',
#  '아메리칸 팩토리',
#  '아메리칸 팩토리',
#  '더 쇼트 게임',
#  '더 쇼트 게임',
#  '더 쇼트 게임',
#  '더 쇼트 게임',
#  '더 쇼트 게임',
#  '샌디 웩슬러',
#  '더 쇼트 게임',
#  '더 쇼트 게임',
#  '몸을 죽이는 자본의 밥상',
#  '몸을 죽이는 자본의 밥상',
#  '토니 로빈스 - 멘토는 내 안에 있다',
#  '클로버필드 패러독스',
#  '클로버필드 패러독스',
#  '클로버필드 패러독스',
#  '커런트 워',
#  '커런트 워',
#  '커런트 워',
#  '커런트 워',
#  '국제수사',
#  '미드나이트 스카이',
#  '미드나이트 스카이',
#  '해피엔드',
#  '어바웃 타임',
#  '인비저블맨',
#  '인비저블맨',
#  '로즈 아일랜드 공화국',
#  '로즈 아일랜드 공화국',
#  '로즈 아일랜드 공화국',
#  '로즈 아일랜드 공화국',
#  '미드나잇 인 파리',
#  '흑사회',
#  '아메리칸 셰프',
#  '아메리칸 셰프',
#  '미지와의 조우',
#  '미지와의 조우',
#  '미지와의 조우',
#  '해피엔드',
#  '쌍화점',
#  '쌍화점',
#  '상류사회',
#  '돈의 맛',
#  '후궁：제왕의 첩',
#  '쌍화점',
#  '해피엔드',
#  '해피엔드',
#  '바람 바람 바람',
#  'NullCompleteVideo',
#  '미지와의 조우',
#  '은교',
#  '은교',
#  '해피엔드',
#  '해피엔드',
#  '스코어',
#  '엠마',
#  '엠마',
#  '엠마',
#  '엠마',
#  '홀로그램 포더 킹',
#  '홀로그램 포더 킹',
#  '홀로그램 포더 킹',
#  '홀로그램 포더 킹',
#  '해피엔드',
#  '화이트 걸',
#  '365일',
#  '뉴니스',
#  '킹 코브라',
#  '21',
#  '해피엔드',
#  '블러드 샷',
#  '블러드 샷',
#  '그레이트 월',
#  '블러드 샷',
#  '블러드 샷',
#  '해피엔드',
#  '도마 위의 정사',
#  '해피엔드',
#  '상류사회',
#  '그 후',
#  '후궁：제왕의 첩',
#  '해피엔드',
#  '쌍화점',
#  '반도',
#  '반도',
#  '반도',
#  '해피엔드',
#  '남과 여',
#  '늑대의 어둠',
#  '늑대의 어둠',
#  '늑대의 어둠',
#  '마담 뺑덕',
#  '해피엔드',
#  '등산의 목적',
#  '지금 사랑하는 사람과 살고 있습니까?',
#  '리디큘러스 6',
#  '리디큘러스 6',
#  '리디큘러스 6',
#  '에놀라 홈즈',
#  '악마는 사라지지 않는다',
#  '붉은 10월',
#  '붉은 10월',
#  '에놀라 홈즈',
#  '블레이드 러너 2049',
#  '블레이드 러너 2049',
#  '블레이드 러너 2049',
#  '등산의 목적',
#  '후궁：제왕의 첩',
#  '등산의 목적',
#  '등산의 목적',
#  '프랭크 캐프라의 일본 견문록',
#  '킹메이커 로저 스톤',
#  '사자',
#  '사자',
#  '심연',
#  '등산의 목적',
#  '등산의 목적',
#  '유혹',
#  '타짜-신의손',
#  '타짜-신의손',
#  '심연',
#  '심연',
#  '작은 아씨들',
#  '등산의 목적',
#  '붉은 바캉스 검은 웨딩',
#  '범죄도시',
#  '젠틀맨 리그',
#  '범죄도시',
#  '2012',
#  '간신',
#  '간신',
#  '아웃로 킹',
#  '건 시티 바르셀로나',
#  '히트맨',
#  '히트맨',
#  '히트맨',
#  '인페르노',
#  '인페르노',
#  '인페르노',
#  '인페르노',
#  '인페르노',
#  '인페르노',
#  '인페르노',
#  '인페르노',
#  '라바 아일랜드 무비',
#  '라바 아일랜드 무비',
#  '하트 오브 더 씨',
#  '스파이 브릿지',
#  '스파이 브릿지',
#  '폴 프롬 그레이스',
#  '폴 프롬 그레이스',
#  '폴 프롬 그레이스',
#  '프로젝트 파워',
#  '프로젝트 파워',
#  '로드 투 퍼디션',
#  '프로젝트 파워',
#  '프로젝트 파워',
#  '프로젝트 파워',
#  '머니 몬스터',
#  '줄리 & 줄리아',
#  '등산의 목적',
#  '방자전',
#  '후궁：제왕의 첩',
#  '인간중독',
#  '타운',
#  '바디 오브 라이즈',
#  '해피엔드',
#  '어카운턴트',
#  '어카운턴트',
#  '봉오동 전투',
#  '해피엔드',
#  '어카운턴트',
#  '루시',
#  '루시',
#  '루시',
#  '루시',
#  '루시',
#  '루시',
#  '루시',
#  '루시',
#  '루시',
#  '루시',
#  '비치',
#  '레볼루셔너리 로드',
#  '올드 가드',
#  '올드 가드',
#  '올드 가드',
#  '마담 뺑덕',
#  '방자전',
#  '유혹',
#  '가루지기',
#  '방자전',
#  '마담 뺑덕',
#  '후궁：제왕의 첩',
#  '머니 몬스터',
#  '번 애프터 리딩',
#  '번 애프터 리딩',
#  '번 애프터 리딩',
#  '파괴자들',
#  '파괴자들',
#  '파괴자들',
#  '파괴자들',
#  '파괴자들',
#  '파괴자들',
#  '해피엔드',
#  '해피엔드',
#  '마담 뺑덕',
#  '은하',
#  '밀애',
#  '유혹',
#  '붉은 바캉스 검은 웨딩',
#  '붉은 바캉스 검은 웨딩',
#  '마담 뺑덕',
#  '밀애',
#  '마담 뺑덕',
#  '은하',
#  '링컨',
#  '콘트라밴드',
#  '카지노',
#  '카지노',
#  '밀애',
#  '머큐리',
#  '6번째 날',
#  '머큐리',
#  '머큐리',
#  '방자전',
#  '간신',
#  '방자전',
#  '링컨',
#  '가을의 전설',
#  '6번째 날',
#  '행오버 3',
#  '행오버 3',
#  '방자전',
#  '해피엔드',
#  '해피엔드',
#  '와인을 딸 시간',
#  '링컨',
#  '링컨',
#  '콘스탄틴',
#  '콘스탄틴',
#  '내셔널 트레져',
#  '라이징 하이',
#  '콘스탄틴',
#  '익스트랙션',
#  '익스트랙션',
#  '라이징 하이',
#  '유혹',
#  '원스 어폰 어 타임 인... 할리우드',
#  '마녀 배달부 키키',
#  '마녀 배달부 키키',
#  '하울의 움직이는 성',
#  '해피엔드',
#  '사랑과 영혼',
#  '코드 8',
#  '프로메테우스',
#  '프로메테우스',
#  '모터싸이클 다이어리',
#  '모터싸이클 다이어리',
#  '버드맨',
#  '버드맨',
#  '우리는 울트라스',
#  '밀리언 웨이즈',
#  '밀리언 웨이즈',
#  '테이큰 3',
#  '6 언더그라운드',
#  '그랜 토리노',
#  ...]

# %%
len(Title_list)
# Out:
# 2133

# %% [markdown]
# ## 중복 제거 X

# %%
import requests
import json
import ast

# %%
# genres_list = []
# for i in range(len(Title_list)):
#   multi_search_api = "https://api.themoviedb.org/3/search/multi?api_key=eac136b19bd53abf1ad95a1444efa985&language=ko&query=%s" %Title_list[i]
#   r = requests.get(multi_search_api)
#   data = json.loads(r.text)

#   genres_li = []
  
#   try:
#     result = data['results'][0]
#     if result is not None:
#       if (result['media_type'] =="movie"):
#         if  result['id'] is not None:
#           movie_id = int(result['id'])

#           movie_api = "https://api.themoviedb.org/3/movie/%d?api_key=eac136b19bd53abf1ad95a1444efa985&language=ko" %movie_id
#           r3 = requests.get(movie_api)
#           data3 = json.loads(r3.text)
#           genres2 = data3["genres"]
#           for k in range(len(genres2)):
#             genres_li.append(genres2[k].get('name'))
#       genres_list.append(genres_li)



#   except:
#     # genres_li.append(np.nan)
#     genres_li.append("없음")
#     genres_list.append(genres_li)

# %%
genres_list = []
for i in range(len(Title_list)):
  multi_search_api = "https://api.themoviedb.org/3/search/multi?api_key=eac136b19bd53abf1ad95a1444efa985&language=ko&query=%s" %Title_list[i]
  r = requests.get(multi_search_api)
  data = json.loads(r.text)

  genres_li = []
  
  try:
    result = data['results'][0]
    if result is not None:
      if (result['media_type'] =="movie"):
        movie_id = int(result['id'])

        movie_api = "https://api.themoviedb.org/3/movie/%d?api_key=eac136b19bd53abf1ad95a1444efa985&language=ko" %movie_id
        r3 = requests.get(movie_api)
        data3 = json.loads(r3.text)
        genres2 = data3["genres"]
        for k in range(len(genres2)):
          genres_li.append(genres2[k].get('name'))
    genres_list.append(genres_li)



  except:
    genres_li.append(np.nan)
    genres_list.append(genres_li)

# %%
genres_list
# Out:
# [['드라마'],
#  ['미스터리', '범죄', 'SF'],
#  ['미스터리', '범죄', 'SF'],
#  ['코미디', '로맨스'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['로맨스', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['드라마', '코미디', '로맨스'],
#  ['코미디', '가족', '로맨스'],
#  ['코미디', '가족', '로맨스'],
#  ['코미디', '가족', '로맨스'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['애니메이션', '가족'],
#  ['코미디', '가족', '로맨스'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['코미디', '드라마', '로맨스'],
#  ['코미디', '드라마', '로맨스'],
#  [nan],
#  ['코미디', '로맨스'],
#  ['공포', '스릴러'],
#  [nan],
#  [nan],
#  [nan],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['공포', '스릴러'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['코미디', '드라마', '로맨스'],
#  ['코미디', '드라마', '로맨스'],
#  [nan],
#  ['코미디', '로맨스'],
#  ['범죄', '드라마', '역사'],
#  ['범죄', '드라마', '역사'],
#  ['범죄', '드라마', '역사'],
#  ['범죄', '드라마', '역사'],
#  ['코미디', '로맨스'],
#  ['다큐멘터리'],
#  ['코미디', '로맨스'],
#  [],
#  [],
#  [],
#  ['로맨스', '코미디', '드라마'],
#  [],
#  ['로맨스', '코미디', '드라마'],
#  ['코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['가족', '애니메이션', '모험', '코미디', '판타지'],
#  ['판타지', '코미디', '로맨스'],
#  ['판타지', '코미디', '로맨스'],
#  ['액션', 'SF', '모험'],
#  ['판타지', '코미디', '로맨스'],
#  ['판타지', '코미디', '로맨스'],
#  ['판타지', '코미디', '로맨스'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디'],
#  ['애니메이션'],
#  [],
#  ['코미디', '드라마', 'SF'],
#  ['코미디', '로맨스'],
#  ['코미디', '판타지', '로맨스'],
#  ['액션', '코미디'],
#  ['범죄', '액션', '드라마'],
#  ['범죄', '액션', '드라마'],
#  ['범죄', '액션', '드라마'],
#  ['미스터리', '액션', '범죄'],
#  ['미스터리', '액션', '범죄'],
#  ['미스터리', '액션', '범죄'],
#  ['스릴러', '미스터리', 'SF'],
#  ['스릴러', '미스터리', 'SF'],
#  ['스릴러', '미스터리', 'SF'],
#  ['로맨스', '드라마'],
#  ['드라마', '코미디'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['애니메이션', '로맨스', '가족'],
#  ['드라마', '가족'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['미스터리', '모험', '드라마'],
#  ['미스터리', '모험', '드라마'],
#  ['드라마', '로맨스'],
#  ['드라마', '코미디'],
#  ['드라마', '로맨스', '판타지', '미스터리'],
#  ['애니메이션', '액션', '모험', '가족', '판타지', '로맨스'],
#  [],
#  [],
#  [],
#  ['드라마'],
#  ['드라마', '역사'],
#  ['애니메이션', '드라마'],
#  [],
#  ['애니메이션', '드라마', '로맨스'],
#  ['애니메이션', '드라마', '로맨스'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  [],
#  ['애니메이션', '드라마', '로맨스'],
#  ['애니메이션', '드라마', '가족'],
#  ['코미디', '드라마'],
#  ['드라마', '코미디', '가족'],
#  ['판타지', '애니메이션', '가족'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['로맨스', '드라마'],
#  ['애니메이션', '드라마'],
#  [],
#  ['판타지', '애니메이션', '가족'],
#  ['판타지', '애니메이션', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '가족'],
#  ['애니메이션', '가족'],
#  ['애니메이션', '모험', '코미디', '판타지'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['드라마', '코미디'],
#  ['코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['액션', '스릴러'],
#  [],
#  ['코미디', '드라마'],
#  ['드라마', '코미디'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['모험', '판타지', '애니메이션'],
#  ['코미디', '범죄', '드라마', '미스터리'],
#  [nan],
#  ['드라마', '로맨스'],
#  ['애니메이션', '드라마'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '코미디'],
#  ['애니메이션', '로맨스', '드라마'],
#  [],
#  ['코미디', '드라마'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['드라마', '판타지', 'SF'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['모험', '애니메이션', '판타지'],
#  ['애니메이션', '판타지', '가족'],
#  ['판타지', '애니메이션', '모험'],
#  ['애니메이션', '판타지', '가족'],
#  ['드라마'],
#  [],
#  ['드라마'],
#  [nan],
#  [nan],
#  ['드라마', '범죄'],
#  ['스릴러', '드라마', '로맨스'],
#  ['미스터리', '범죄', 'SF'],
#  ['범죄', '드라마', '미스터리', '스릴러'],
#  ['스릴러', '범죄'],
#  ['스릴러'],
#  ['코미디', '드라마'],
#  ['로맨스', '드라마'],
#  ['드라마'],
#  [nan],
#  ['드라마', '코미디'],
#  ['스릴러', '드라마'],
#  ['스릴러'],
#  ['코미디', '로맨스'],
#  ['스릴러'],
#  ['드라마', '범죄', '공포', '스릴러'],
#  ['드라마', '범죄'],
#  ['코미디', '판타지', '드라마'],
#  [nan],
#  ['드라마', '역사'],
#  [nan],
#  ['드라마'],
#  ['드라마', '미스터리', '범죄'],
#  ['스릴러'],
#  ['스릴러'],
#  [],
#  ['드라마'],
#  [],
#  ['미스터리', '액션', '범죄'],
#  ['드라마', '범죄'],
#  ['애니메이션', '드라마'],
#  ['드라마'],
#  ['로맨스', '드라마'],
#  ['미스터리', '스릴러'],
#  ['로맨스'],
#  ['드라마', '로맨스'],
#  [nan],
#  ['코미디', '로맨스'],
#  ['애니메이션', '드라마'],
#  ['드라마', '로맨스'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['드라마'],
#  ['코미디', '드라마'],
#  ['드라마', '로맨스'],
#  ['드라마', '미스터리', '로맨스', '스릴러'],
#  ['로맨스', '드라마'],
#  ['드라마', '로맨스'],
#  ['애니메이션', '가족', '판타지'],
#  ['애니메이션', '가족', '판타지'],
#  ['애니메이션', '가족', '판타지'],
#  ['애니메이션', '가족', '판타지'],
#  ['드라마'],
#  [nan],
#  ['코미디', '드라마'],
#  ['드라마'],
#  [],
#  ['애니메이션', '가족', '판타지'],
#  ['액션', 'SF', '모험'],
#  ['애니메이션', '드라마', '로맨스', '판타지'],
#  ['애니메이션', '드라마'],
#  ['드라마', '로맨스'],
#  [nan],
#  ['코미디'],
#  ['드라마', '범죄', '공포', '스릴러'],
#  ['판타지', '애니메이션', '모험'],
#  ['판타지', '애니메이션', '모험'],
#  ['판타지', '애니메이션', '모험'],
#  ['판타지', '애니메이션', '모험'],
#  ['판타지', '애니메이션', '모험'],
#  [],
#  ['모험', '판타지', '애니메이션', '드라마', '가족'],
#  ['모험', '판타지', '애니메이션', '드라마', '가족'],
#  ['판타지', '애니메이션', '가족'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  [nan],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['애니메이션', '드라마', '판타지'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  [],
#  ['로맨스', '코미디', '드라마'],
#  [nan],
#  ['드라마'],
#  ['드라마'],
#  ['코미디'],
#  ['액션', '스릴러'],
#  ['드라마'],
#  ['로맨스', '드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['액션', '스릴러'],
#  ['드라마'],
#  ['액션', '드라마', '로맨스', '스릴러'],
#  ['액션', '모험', '코미디', 'SF'],
#  ['액션', '모험', '코미디', 'SF'],
#  ['액션', '스릴러'],
#  ['드라마'],
#  ['드라마', '음악', '로맨스'],
#  ['역사', '드라마'],
#  ['드라마', '로맨스'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  [nan],
#  ['액션', '드라마', '로맨스', '스릴러'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '로맨스', '모험'],
#  [nan],
#  ['드라마'],
#  [nan],
#  ['로맨스', '드라마'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  [nan],
#  [nan],
#  ['코미디', '가족', '드라마'],
#  ['드라마'],
#  ['범죄', '액션', 'SF'],
#  ['범죄', '액션', 'SF'],
#  ['드라마'],
#  ['모험', '역사', '드라마'],
#  ['모험', '역사', '드라마'],
#  ['드라마'],
#  ['모험', '드라마', '가족'],
#  ['드라마', '애니메이션'],
#  ['공포', '코미디', '범죄', '스릴러'],
#  ['다큐멘터리'],
#  ['드라마', '미스터리', '범죄'],
#  [],
#  ['드라마'],
#  ['드라마'],
#  ['다큐멘터리', '음악'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [nan],
#  [nan],
#  ['코미디', '가족', '드라마'],
#  ['드라마'],
#  ['모험', '드라마', '역사', '로맨스'],
#  ['로맨스', '코미디'],
#  ['스릴러', '액션'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['로맨스', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['로맨스', '코미디'],
#  ['액션', '범죄'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['드라마', '서부'],
#  ['드라마', '서부'],
#  ['드라마'],
#  ['코미디', '로맨스'],
#  ['SF', '코미디'],
#  ['SF', '코미디'],
#  ['SF', '코미디'],
#  [],
#  ['SF', '코미디'],
#  [],
#  ['모험', '드라마', '스릴러'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['드라마', '로맨스'],
#  ['로맨스', '드라마', '역사'],
#  [nan],
#  ['전쟁', '드라마', '액션', '스릴러'],
#  ['드라마', '로맨스'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['코미디', '로맨스'],
#  ['역사', '드라마'],
#  [],
#  ['드라마'],
#  ['드라마'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['액션', '코미디'],
#  [],
#  ['드라마'],
#  ['드라마'],
#  [nan],
#  ['범죄', '스릴러', '액션'],
#  ['범죄', '스릴러', '액션'],
#  ['범죄', '스릴러', '액션'],
#  ['SF', '스릴러'],
#  ['판타지', '로맨스'],
#  ['판타지', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['SF', '스릴러'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['액션', 'SF'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['액션', 'SF'],
#  [],
#  ['스릴러', '미스터리'],
#  ['스릴러', '미스터리'],
#  ['스릴러', '미스터리'],
#  ['모험', '드라마'],
#  [nan],
#  ['액션', '코미디'],
#  ['코미디'],
#  ['범죄', '드라마', '액션'],
#  ['로맨스', '스릴러'],
#  ['역사', '코미디'],
#  ['스릴러', 'SF', '미스터리'],
#  ['범죄', '액션'],
#  ['로맨스', '코미디'],
#  ['공포', '스릴러'],
#  ['판타지', '코미디', '로맨스'],
#  ['드라마', '역사'],
#  [],
#  [nan],
#  [],
#  ['코미디', '드라마', '전쟁'],
#  [],
#  ['판타지', '드라마', '로맨스'],
#  [],
#  ['범죄', '스릴러', '드라마'],
#  ['모험', '드라마', '로맨스', '전쟁', '서부'],
#  ['액션', '코미디', '범죄', '스릴러'],
#  ['액션', '모험', 'SF'],
#  ['코미디', '드라마', 'SF'],
#  ['코미디', '드라마', 'SF'],
#  ['전쟁', '드라마', '액션'],
#  ['전쟁', '드라마', '액션'],
#  ['전쟁', '드라마', '액션'],
#  ['로맨스', '드라마'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스', '모험'],
#  ['드라마', '로맨스', '모험'],
#  ['전쟁', '드라마', '액션'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['코미디', '드라마'],
#  ['액션', '스릴러'],
#  ['코미디', '드라마'],
#  [nan],
#  ['드라마'],
#  ['역사', '드라마'],
#  ['역사', '드라마'],
#  ['역사', '드라마'],
#  ['역사', '드라마'],
#  [],
#  [],
#  ['코미디', '드라마', '스릴러'],
#  ['범죄', '드라마', '스릴러', '액션'],
#  ['드라마', '스릴러', '모험', 'SF'],
#  ['드라마', '스릴러', '모험', 'SF'],
#  ['드라마', '역사'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['액션', '드라마', '로맨스', '스릴러'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  [],
#  ['스릴러', '드라마', '로맨스'],
#  [nan],
#  ['액션', '범죄', '스릴러'],
#  [],
#  [],
#  ['서부'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  [],
#  ['액션', '코미디', '범죄', '스릴러'],
#  [nan],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['코미디', '로맨스'],
#  ['액션', '코미디', '범죄', '스릴러'],
#  ['액션', '코미디', '범죄', '스릴러'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스', '모험'],
#  ['코미디', '로맨스'],
#  ['드라마'],
#  [nan],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['로맨스'],
#  [nan],
#  [nan],
#  [nan],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['드라마'],
#  [nan],
#  ['로맨스'],
#  ['로맨스'],
#  ['액션'],
#  ['범죄', '스릴러', '액션'],
#  ['범죄', '스릴러', '액션'],
#  [nan],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['드라마'],
#  [nan],
#  [],
#  ['드라마', '로맨스'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['로맨스', '드라마'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [],
#  [],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['드라마', '로맨스'],
#  ['로맨스', '드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['범죄', '코미디'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['로맨스', '스릴러'],
#  ['드라마', '미스터리'],
#  ['드라마', '미스터리'],
#  ['드라마', '범죄', '스릴러'],
#  ['드라마', '로맨스'],
#  ['드라마', '범죄', '스릴러'],
#  ['드라마', '미스터리'],
#  ['로맨스', '드라마'],
#  ['드라마'],
#  ['코미디', '액션'],
#  ['코미디', '액션'],
#  ['로맨스', '모험', '드라마', '가족', '역사'],
#  ['드라마', '범죄', '스릴러'],
#  ['드라마', '로맨스'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['로맨스', '모험', '드라마', '가족', '역사'],
#  ['로맨스', '모험', '드라마', '가족', '역사'],
#  ['로맨스', '모험', '드라마', '가족', '역사'],
#  ['드라마'],
#  [nan],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['코미디'],
#  ['로맨스', '드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  [],
#  ['로맨스', '드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['범죄', '액션'],
#  ['범죄', '액션'],
#  ['범죄', '액션'],
#  ['범죄', '액션'],
#  ['액션', '범죄', '스릴러'],
#  ['미스터리', '스릴러', '범죄', '코미디', '드라마'],
#  ['액션', '스릴러'],
#  ['액션', '스릴러'],
#  ['액션', '스릴러'],
#  ['드라마', '액션', '역사'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러'],
#  ['드라마'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마', '범죄'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['범죄', '액션', '드라마'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마', '공포', '스릴러'],
#  ['드라마', '코미디', '로맨스'],
#  ['로맨스', '드라마'],
#  ['드라마', '역사'],
#  ['범죄', '드라마', '스릴러', '액션'],
#  ['코미디', '액션', '모험', '판타지'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['범죄'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['드라마'],
#  ['범죄'],
#  ['범죄'],
#  ['드라마'],
#  ['액션', '드라마', '로맨스', '스릴러'],
#  ['다큐멘터리'],
#  ['드라마'],
#  [nan],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '범죄'],
#  ['스릴러', '드라마'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  [],
#  [],
#  ['드라마', '역사'],
#  ['로맨스', '드라마'],
#  ['액션', '스릴러'],
#  ['액션', '스릴러'],
#  ['드라마', '서부', '모험'],
#  ['드라마', '서부', '모험'],
#  ['드라마', '전쟁', '역사'],
#  ['드라마', '서부', '모험'],
#  ['로맨스', '드라마'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마', '범죄', '공포', '스릴러'],
#  ['스릴러'],
#  ['드라마'],
#  ['스릴러', '드라마'],
#  ['드라마', '판타지', 'SF'],
#  ['드라마', '판타지', 'SF'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마', '스릴러', 'SF'],
#  ['드라마', '스릴러', 'SF'],
#  ['드라마', '스릴러', 'SF'],
#  ['드라마', '스릴러', 'SF'],
#  ['스릴러', '액션'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['스릴러', '드라마', '로맨스'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['드라마'],
#  ['SF'],
#  ['스릴러', '액션', 'SF'],
#  ['스릴러', '액션', 'SF'],
#  ['스릴러', '액션', 'SF'],
#  ['스릴러', '액션', 'SF'],
#  ['액션', '스릴러'],
#  ['액션', '스릴러'],
#  ['액션', '드라마', '로맨스', '스릴러'],
#  ['드라마', '로맨스'],
#  ['드라마'],
#  ['코미디'],
#  ['코미디'],
#  ['액션', '드라마', '로맨스', '스릴러'],
#  ['전쟁', '역사', '액션'],
#  ['SF', '드라마', '미스터리', '스릴러'],
#  ['스릴러', 'SF', '미스터리', '로맨스'],
#  ['스릴러', 'SF', '미스터리', '로맨스'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['액션'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['SF', '스릴러'],
#  ['SF', '스릴러'],
#  ['SF'],
#  ['SF'],
#  ['SF'],
#  ['드라마'],
#  ['애니메이션', '드라마'],
#  ['드라마', '로맨스'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['코미디'],
#  [nan],
#  [nan],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['공포', 'SF', '액션', '스릴러'],
#  [],
#  [],
#  [],
#  [],
#  ['범죄', '코미디', '액션'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['드라마'],
#  ['드라마', '로맨스', '판타지'],
#  ['스릴러', 'SF', '공포'],
#  ['스릴러', 'SF', '공포'],
#  ['코미디', '모험'],
#  ['코미디', '모험'],
#  ['코미디', '모험'],
#  ['코미디', '모험'],
#  ['판타지', '코미디', '로맨스'],
#  ['드라마', '범죄'],
#  ['코미디'],
#  ['코미디'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '범죄'],
#  ['드라마'],
#  [nan],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['코미디'],
#  [nan],
#  ['SF', '드라마'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['드라마'],
#  ['드라마'],
#  ['스릴러'],
#  [],
#  [],
#  [],
#  [],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['로맨스', '드라마'],
#  ['범죄', '드라마'],
#  [],
#  ['드라마'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['드라마'],
#  ['스릴러'],
#  ['드라마'],
#  ['드라마', '범죄'],
#  ['드라마', '로맨스'],
#  [nan],
#  ['드라마'],
#  ['드라마'],
#  ['액션', '공포', '스릴러'],
#  ['액션', '공포', '스릴러'],
#  ['액션', '공포', '스릴러'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['스릴러', '미스터리', '범죄'],
#  ['스릴러', '미스터리', '범죄'],
#  ['스릴러', '미스터리', '범죄'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['로맨스'],
#  ['서부', '코미디'],
#  ['서부', '코미디'],
#  ['서부', '코미디'],
#  ['미스터리', '모험', '드라마'],
#  ['범죄', '드라마', '스릴러'],
#  ['액션', '모험', '스릴러'],
#  ['액션', '모험', '스릴러'],
#  ['미스터리', '모험', '드라마'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['드라마', '로맨스'],
#  [nan],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  [nan],
#  ['다큐멘터리', '역사'],
#  ['액션', '공포'],
#  ['액션', '공포'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  [],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['모험', '액션', '스릴러', 'SF'],
#  [],
#  ['드라마', '로맨스'],
#  ['드라마'],
#  ['범죄', '액션'],
#  ['판타지', '액션', '스릴러', 'SF'],
#  ['범죄', '액션'],
#  ['액션', '모험', 'SF'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['액션', '역사', '드라마', '전쟁'],
#  ['드라마', '범죄', '스릴러'],
#  ['액션', '코미디'],
#  ['액션', '코미디'],
#  ['액션', '코미디'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['애니메이션', '가족'],
#  ['애니메이션', '가족'],
#  ['애니메이션', '모험', '코미디', '판타지', '액션'],
#  ['스릴러', '드라마'],
#  ['스릴러', '드라마'],
#  ['드라마', '판타지', '스릴러'],
#  ['드라마', '판타지', '스릴러'],
#  ['드라마', '판타지', '스릴러'],
#  ['액션', '범죄', 'SF'],
#  ['액션', '범죄', 'SF'],
#  ['범죄', '드라마', '스릴러'],
#  ['액션', '범죄', 'SF'],
#  ['액션', '범죄', 'SF'],
#  ['액션', '범죄', 'SF'],
#  ['스릴러', '드라마'],
#  [],
#  ['드라마', '로맨스'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  [nan],
#  ['드라마', '로맨스', '모험'],
#  ['드라마'],
#  ['액션', '드라마', '스릴러'],
#  ['드라마'],
#  ['범죄', '스릴러', '드라마'],
#  ['범죄', '스릴러', '드라마'],
#  ['역사', '액션', '전쟁'],
#  ['드라마'],
#  ['범죄', '스릴러', '드라마'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['코미디', '드라마', '스릴러'],
#  ['드라마', '로맨스'],
#  ['액션', '모험', '스릴러'],
#  ['액션', '모험', '스릴러'],
#  ['액션', '모험', '스릴러'],
#  ['스릴러', '드라마', '로맨스'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  [],
#  ['코미디', '판타지', '드라마'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['스릴러', '드라마', '로맨스'],
#  [nan],
#  ['스릴러', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['드라마'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['로맨스', '드라마'],
#  [],
#  ['드라마'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['로맨스', '드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['역사', '드라마'],
#  ['스릴러', '액션', '드라마', '범죄'],
#  [],
#  [],
#  ['로맨스', '드라마'],
#  ['다큐멘터리'],
#  ['SF', '미스터리', '액션'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['드라마', '역사'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['역사', '드라마'],
#  ['모험', '드라마', '로맨스', '전쟁', '서부'],
#  ['SF', '미스터리', '액션'],
#  ['코미디'],
#  ['코미디'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '코미디'],
#  ['역사', '드라마'],
#  ['역사', '드라마'],
#  [],
#  [],
#  [],
#  ['코미디', '드라마'],
#  [],
#  ['드라마', '액션', '스릴러'],
#  ['드라마', '액션', '스릴러'],
#  ['코미디', '드라마'],
#  [],
#  ['코미디', '드라마', '스릴러'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['판타지', '애니메이션', '모험'],
#  ['드라마'],
#  ['가족', '코미디'],
#  ['SF', '액션', '범죄', '스릴러', '드라마'],
#  ['SF', '모험', '미스터리'],
#  ['SF', '모험', '미스터리'],
#  ['드라마'],
#  ['드라마'],
#  ['범죄', '드라마'],
#  ['범죄', '드라마'],
#  ['드라마'],
#  ['코미디', '서부'],
#  ['코미디', '서부'],
#  ['스릴러', '액션'],
#  ['다큐멘터리'],
#  ['드라마'],
#  ...]

# %%
len(genres_list)
# Out:
# 2133

# %%
genres = pd.DataFrame(genres_list, columns = ["genre1", "genre2", "genre3", "genre4", "genre5", "genre6"])
genres
# Out:
#      genre1 genre2 genre3 genre4 genre5 genre6
# 0       드라마   None   None   None   None   None
# 1      미스터리     범죄     SF   None   None   None
# 2      미스터리     범죄     SF   None   None   None
# 3       코미디    로맨스   None   None   None   None
# 4       로맨스    코미디   None   None   None   None
# ...     ...    ...    ...    ...    ...    ...
# 2128  다큐멘터리   None   None   None   None   None
# 2129   None   None   None   None   None   None
# 2130     액션     모험    판타지     SF   None   None
# 2131    NaN   None   None   None   None   None
# 2132    코미디    판타지    로맨스   None   None   None
#
# [2133 rows x 6 columns]

# %%
len(genres)
# Out:
# 2133

# %%
g1 = (genres["genre1"].value_counts())
g1
# Out:
# 드라마      383
# 코미디      307
# 액션       173
# 스릴러      136
# 로맨스      129
# 다큐멘터리     90
# 범죄        85
# 애니메이션     79
# 모험        77
# 판타지       72
# 공포        60
# SF        55
# 미스터리      30
# 가족        29
# 역사        12
# 전쟁         7
# 서부         6
# 음악         2
# TV 영화      2
# Name: genre1, dtype: int64

# %%
g1 =pd.DataFrame(genres["genre1"].value_counts())

# %%
g2 =pd.DataFrame(genres["genre2"].value_counts())
g2
# Out:
#        genre2
# 드라마       284
# 코미디       231
# 로맨스       143
# 액션        128
# 스릴러        98
# 모험         82
# 범죄         76
# 미스터리       57
# 애니메이션      56
# 판타지        53
# SF         42
# 가족         39
# 역사         30
# 음악         15
# 공포         13
# 서부         12
# TV 영화       3
# 전쟁          2

# %%
g3 =pd.DataFrame(genres["genre3"].value_counts())
g3
# Out:
#        genre3
# 로맨스       106
# 스릴러        89
# 드라마        86
# SF         75
# 모험         62
# 가족         56
# 코미디        52
# 판타지        50
# 범죄         46
# 역사         43
# 액션         36
# 미스터리       30
# 애니메이션      12
# 공포         11
# 음악          9
# 전쟁          4
# TV 영화       4

# %%
g4 =pd.DataFrame(genres["genre4"].value_counts())
g4
# Out:
#        genre4
# 스릴러        39
# 코미디        33
# SF         31
# 판타지        29
# 미스터리       25
# 가족         14
# 모험         13
# 드라마        12
# 액션         11
# 공포          8
# 범죄          8
# 로맨스         4
# 전쟁          3
# 역사          1
# 애니메이션       1

# %%
g5 =pd.DataFrame(genres["genre5"].value_counts())
g5
# Out:
#      genre5
# 판타지       8
# 역사        7
# 가족        6
# 범죄        6
# 드라마       5
# 코미디       5
# 서부        2
# 액션        2
# 스릴러       2
# 모험        1

# %%
g6 =pd.DataFrame(genres["genre6"].value_counts())
g6
# Out:
#      genre6
# 음악        5
# 로맨스       4
# 판타지       1

# %%
genre_total = pd.concat([g1,g2,g3,g4,g5,g6], axis=1)
genre_total
# Out:
#        genre1  genre2  genre3  genre4  genre5  genre6
# 드라마       383   284.0    86.0    12.0     5.0     NaN
# 코미디       307   231.0    52.0    33.0     5.0     NaN
# 액션        173   128.0    36.0    11.0     2.0     NaN
# 스릴러       136    98.0    89.0    39.0     2.0     NaN
# 로맨스       129   143.0   106.0     4.0     NaN     4.0
# 다큐멘터리      90     NaN     NaN     NaN     NaN     NaN
# 범죄         85    76.0    46.0     8.0     6.0     NaN
# 애니메이션      79    56.0    12.0     1.0     NaN     NaN
# 모험         77    82.0    62.0    13.0     1.0     NaN
# 판타지        72    53.0    50.0    29.0     8.0     1.0
# 공포         60    13.0    11.0     8.0     NaN     NaN
# SF         55    42.0    75.0    31.0     NaN     NaN
# 미스터리       30    57.0    30.0    25.0     NaN     NaN
# 가족         29    39.0    56.0    14.0     6.0     NaN
# 역사         12    30.0    43.0     1.0     7.0     NaN
# 전쟁          7     2.0     4.0     3.0     NaN     NaN
# 서부          6    12.0     NaN     NaN     2.0     NaN
# 음악          2    15.0     9.0     NaN     NaN     5.0
# TV 영화       2     3.0     4.0     NaN     NaN     NaN

# %%
genre_total["sum"] = genre_total.sum(axis=1)
genre_total.reset_index().rename(columns={"index":"genre"})
# Out:
#     genre  genre1  genre2  genre3  genre4  genre5  genre6    sum
# 0     드라마     383   284.0    86.0    12.0     5.0     NaN  770.0
# 1     코미디     307   231.0    52.0    33.0     5.0     NaN  628.0
# 2      액션     173   128.0    36.0    11.0     2.0     NaN  350.0
# 3     스릴러     136    98.0    89.0    39.0     2.0     NaN  364.0
# 4     로맨스     129   143.0   106.0     4.0     NaN     4.0  386.0
# 5   다큐멘터리      90     NaN     NaN     NaN     NaN     NaN   90.0
# 6      범죄      85    76.0    46.0     8.0     6.0     NaN  221.0
# 7   애니메이션      79    56.0    12.0     1.0     NaN     NaN  148.0
# 8      모험      77    82.0    62.0    13.0     1.0     NaN  235.0
# 9     판타지      72    53.0    50.0    29.0     8.0     1.0  213.0
# 10     공포      60    13.0    11.0     8.0     NaN     NaN   92.0
# 11     SF      55    42.0    75.0    31.0     NaN     NaN  203.0
# 12   미스터리      30    57.0    30.0    25.0     NaN     NaN  142.0
# 13     가족      29    39.0    56.0    14.0     6.0     NaN  144.0
# 14     역사      12    30.0    43.0     1.0     7.0     NaN   93.0
# 15     전쟁       7     2.0     4.0     3.0     NaN     NaN   16.0
# 16     서부       6    12.0     NaN     NaN     2.0     NaN   20.0
# 17     음악       2    15.0     9.0     NaN     NaN     5.0   31.0
# 18  TV 영화       2     3.0     4.0     NaN     NaN     NaN    9.0

# %%
genre_total = genre_total.sort_values(by=["sum"],ascending=False)
genre_total
# Out:
#        genre1  genre2  genre3  genre4  genre5  genre6    sum
# 드라마       383   284.0    86.0    12.0     5.0     NaN  770.0
# 코미디       307   231.0    52.0    33.0     5.0     NaN  628.0
# 로맨스       129   143.0   106.0     4.0     NaN     4.0  386.0
# 스릴러       136    98.0    89.0    39.0     2.0     NaN  364.0
# 액션        173   128.0    36.0    11.0     2.0     NaN  350.0
# 모험         77    82.0    62.0    13.0     1.0     NaN  235.0
# 범죄         85    76.0    46.0     8.0     6.0     NaN  221.0
# 판타지        72    53.0    50.0    29.0     8.0     1.0  213.0
# SF         55    42.0    75.0    31.0     NaN     NaN  203.0
# 애니메이션      79    56.0    12.0     1.0     NaN     NaN  148.0
# 가족         29    39.0    56.0    14.0     6.0     NaN  144.0
# 미스터리       30    57.0    30.0    25.0     NaN     NaN  142.0
# 역사         12    30.0    43.0     1.0     7.0     NaN   93.0
# 공포         60    13.0    11.0     8.0     NaN     NaN   92.0
# 다큐멘터리      90     NaN     NaN     NaN     NaN     NaN   90.0
# 음악          2    15.0     9.0     NaN     NaN     5.0   31.0
# 서부          6    12.0     NaN     NaN     2.0     NaN   20.0
# 전쟁          7     2.0     4.0     3.0     NaN     NaN   16.0
# TV 영화       2     3.0     4.0     NaN     NaN     NaN    9.0

# %% [markdown]
# ### Top5 추출

# %%
top5 = genre_total.iloc[:5]
top5 = top5.reset_index()
top5 = top5.fillna(value =0)
top5
# Out:
#   index  genre1  genre2  genre3  genre4  genre5  genre6    sum
# 0   드라마     383   284.0    86.0    12.0     5.0     0.0  770.0
# 1   코미디     307   231.0    52.0    33.0     5.0     0.0  628.0
# 2   로맨스     129   143.0   106.0     4.0     0.0     4.0  386.0
# 3   스릴러     136    98.0    89.0    39.0     2.0     0.0  364.0
# 4    액션     173   128.0    36.0    11.0     2.0     0.0  350.0

# %% [markdown]
# ### Radar chart

# %%
categories = top5["index"]
categories = [*categories, categories[0]]

top5_sum = top5["sum"]
sum = [*top5_sum, top5_sum[0]]


label_loc = np.linspace(start=0, stop=2*np.pi, num=len(sum))


plt.figure(figsize=(8,8))
ax = plt.subplot(polar=True)
plt.xticks(label_loc, labels=categories, fontsize=13)
ax.plot(label_loc, sum, label='genre', linestyle='dashed', color='lightcoral')
ax.fill(label_loc, sum, color='lightcoral', alpha=0.3)
ax.legend()
plt.show()

# %% [markdown]
# ## 중복 제거
# 같은 년, 월, 일 경우만 하나로 통일

# %%
Movies_no_duple = Movies[Movies .duplicated(["Title", "Year", "Month", "Day"], keep=False)]
Movies_no_duple
# Out:
#      Profile Name          Start Time  Duration  \
# 1           guest 2021-05-30 12:46:21  00:47:35
# 2           guest 2021-05-30 11:25:03  00:26:49
# 3           guest 2020-09-25 15:32:39  00:24:28
# 4           guest 2020-09-25 14:27:15  01:00:15
# 5           guest 2020-09-25 11:30:51  00:43:31
# ...           ...                 ...       ...
# 2107          김지은 2020-01-05 14:43:13  00:13:53
# 2108          김지은 2020-01-05 11:41:16  00:13:27
# 2109          김지은 2020-01-05 11:27:35  00:13:05
# 2116          김지은 2019-09-21 08:46:40  00:46:52
# 2117          김지은 2019-09-21 07:54:17  00:31:50
#
#                                   Attributes     Title  \
# 1                                        NaN  라플라스의 마녀
# 2                                        NaN  라플라스의 마녀
# 3     Autoplayed: user action: Unspecified;    키싱 부스 2
# 4                                        NaN     키싱 부스
# 5            Autoplayed: user action: None;      키싱 부스
# ...                                      ...       ...
# 2107                                     NaN     씨스터액트
# 2108                                     NaN     씨스터액트
# 2109                                     NaN     씨스터액트
# 2116                                     NaN       톨 걸
# 2117                                     NaN       톨 걸
#
#      Supplemental Video Type           Device Type  Bookmark  Latest Bookmark  \
# 1                        NaN  Safari MAC (Cadmium)  01:10:36         01:10:36
# 2                        NaN  Safari MAC (Cadmium)  00:26:49  Not latest view
# 3                        NaN  Safari MAC (Cadmium)  00:24:28         00:24:28
# 4                        NaN  Safari MAC (Cadmium)  01:43:46         01:43:46
# 5                        NaN  Safari MAC (Cadmium)  00:43:31  Not latest view
# ...                      ...                   ...       ...              ...
# 2107                     NaN  Safari MAC (Cadmium)  00:45:32  Not latest view
# 2108                     NaN  Safari MAC (Cadmium)  00:26:32  Not latest view
# 2109                     NaN  Safari MAC (Cadmium)  00:13:05  Not latest view
# 2116                     NaN       Apple iPhone 6s  01:38:47         01:38:47
# 2117                     NaN       Apple iPhone 6s  00:34:30  Not latest view
#
#                       Country  ...  Month  Day  Day_name Hour  Minute  Second  \
# 1     KR (Korea, Republic of)  ...      5   30    Sunday   12      46      21
# 2     KR (Korea, Republic of)  ...      5   30    Sunday   11      25       3
# 3     KR (Korea, Republic of)  ...      9   25    Friday   15      32      39
# 4     KR (Korea, Republic of)  ...      9   25    Friday   14      27      15
# 5     KR (Korea, Republic of)  ...      9   25    Friday   11      30      51
# ...                       ...  ...    ...  ...       ...  ...     ...     ...
# 2107  KR (Korea, Republic of)  ...      1    5    Sunday   14      43      13
# 2108  KR (Korea, Republic of)  ...      1    5    Sunday   11      41      16
# 2109  KR (Korea, Republic of)  ...      1    5    Sunday   11      27      35
# 2116  KR (Korea, Republic of)  ...      9   21  Saturday    8      46      40
# 2117  KR (Korea, Republic of)  ...      9   21  Saturday    7      54      17
#
#       Duration_hour Duration_min Duration_sec Duration_sec_sum
# 1                00           47           35             2855
# 2                00           26           49             1609
# 3                00           24           28             1468
# 4                01           00           15               75
# 5                00           43           31             2611
# ...             ...          ...          ...              ...
# 2107             00           13           53              833
# 2108             00           13           27              807
# 2109             00           13           05              785
# 2116             00           46           52             2812
# 2117             00           31           50             1910
#
# [1032 rows x 21 columns]

# %%
len(Movies_no_duple)
# Out:
# 1032

# %%
Title_list= list(Movies_no_duple["Title"])

# %%
import requests
import json
import ast

# %%
genres_list = []
for i in range(len(Title_list)):
  multi_search_api = "https://api.themoviedb.org/3/search/multi?api_key=eac136b19bd53abf1ad95a1444efa985&language=ko&query=%s" %Title_list[i]
  r = requests.get(multi_search_api)
  data = json.loads(r.text)

  genres_li = []
  
  try:
    result = data['results'][0]
    if result is not None:
      if (result['media_type'] =="movie"):
        movie_id = int(result['id'])

        movie_api = "https://api.themoviedb.org/3/movie/%d?api_key=eac136b19bd53abf1ad95a1444efa985&language=ko" %movie_id
        r3 = requests.get(movie_api)
        data3 = json.loads(r3.text)
        genres2 = data3["genres"]
        for k in range(len(genres2)):
          genres_li.append(genres2[k].get('name'))
    genres_list.append(genres_li)



  except:
    genres_li.append(np.nan)
    genres_list.append(genres_li)

# %%
genres_list
# Out:
# [['미스터리', '범죄', 'SF'],
#  ['미스터리', '범죄', 'SF'],
#  ['코미디', '로맨스'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '가족', '로맨스'],
#  ['코미디', '가족', '로맨스'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['코미디', '드라마', '로맨스'],
#  ['코미디', '드라마', '로맨스'],
#  [nan],
#  [nan],
#  [nan],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['코미디', '드라마', '로맨스'],
#  ['코미디', '드라마', '로맨스'],
#  ['범죄', '드라마', '역사'],
#  ['범죄', '드라마', '역사'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  [],
#  [],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['판타지', '코미디', '로맨스'],
#  ['판타지', '코미디', '로맨스'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디', '드라마'],
#  ['로맨스', '코미디', '드라마'],
#  ['코미디', '드라마', 'SF'],
#  ['범죄', '액션', '드라마'],
#  ['범죄', '액션', '드라마'],
#  ['범죄', '액션', '드라마'],
#  ['미스터리', '액션', '범죄'],
#  ['미스터리', '액션', '범죄'],
#  ['스릴러', '미스터리', 'SF'],
#  ['스릴러', '미스터리', 'SF'],
#  ['스릴러', '미스터리', 'SF'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  [],
#  [],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  [],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['애니메이션', '드라마', '가족'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  ['애니메이션', '판타지', '가족'],
#  [nan],
#  [nan],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['애니메이션', '가족', '판타지'],
#  ['애니메이션', '가족', '판타지'],
#  ['애니메이션', '가족', '판타지'],
#  ['애니메이션', '가족', '판타지'],
#  ['판타지', '애니메이션', '모험'],
#  ['판타지', '애니메이션', '모험'],
#  ['판타지', '애니메이션', '모험'],
#  ['판타지', '애니메이션', '모험'],
#  ['모험', '판타지', '애니메이션', '드라마', '가족'],
#  ['모험', '판타지', '애니메이션', '드라마', '가족'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['드라마'],
#  ['드라마'],
#  ['액션', '스릴러'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['액션', '스릴러'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  [nan],
#  [nan],
#  ['범죄', '액션', 'SF'],
#  ['범죄', '액션', 'SF'],
#  ['모험', '역사', '드라마'],
#  ['모험', '역사', '드라마'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [nan],
#  [nan],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['드라마', '코미디'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['드라마', '서부'],
#  ['드라마', '서부'],
#  ['SF', '코미디'],
#  ['SF', '코미디'],
#  ['SF', '코미디'],
#  ['SF', '코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['드라마'],
#  ['드라마'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['드라마'],
#  ['드라마'],
#  ['범죄', '스릴러', '액션'],
#  ['범죄', '스릴러', '액션'],
#  ['범죄', '스릴러', '액션'],
#  ['판타지', '로맨스'],
#  ['판타지', '로맨스'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['액션', 'SF'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['액션', 'SF'],
#  ['스릴러', '미스터리'],
#  ['스릴러', '미스터리'],
#  ['스릴러', '미스터리'],
#  [],
#  [],
#  ['코미디', '드라마', 'SF'],
#  ['코미디', '드라마', 'SF'],
#  ['전쟁', '드라마', '액션'],
#  ['전쟁', '드라마', '액션'],
#  ['전쟁', '드라마', '액션'],
#  ['드라마', '로맨스', '모험'],
#  ['드라마', '로맨스', '모험'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['역사', '드라마'],
#  ['역사', '드라마'],
#  ['역사', '드라마'],
#  ['역사', '드라마'],
#  [],
#  [],
#  ['드라마', '스릴러', '모험', 'SF'],
#  ['드라마', '스릴러', '모험', 'SF'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', '미스터리', '드라마', '공포', '범죄'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['스릴러', 'SF', '미스터리'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  [],
#  [],
#  ['액션', '코미디', '범죄', '스릴러'],
#  ['액션', '코미디', '범죄', '스릴러'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  [nan],
#  [nan],
#  [nan],
#  ['드라마'],
#  ['드라마'],
#  ['로맨스'],
#  ['로맨스'],
#  ['범죄', '스릴러', '액션'],
#  ['범죄', '스릴러', '액션'],
#  ['드라마'],
#  ['드라마'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [],
#  [],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['드라마', '미스터리'],
#  ['드라마', '미스터리'],
#  ['드라마', '범죄', '스릴러'],
#  ['드라마', '범죄', '스릴러'],
#  ['드라마', '미스터리'],
#  ['코미디', '액션'],
#  ['코미디', '액션'],
#  ['로맨스', '모험', '드라마', '가족', '역사'],
#  ['로맨스', '모험', '드라마', '가족', '역사'],
#  ['로맨스', '모험', '드라마', '가족', '역사'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  [],
#  ['범죄', '액션'],
#  ['범죄', '액션'],
#  ['범죄', '액션'],
#  ['범죄', '액션'],
#  ['액션', '스릴러'],
#  ['액션', '스릴러'],
#  ['액션', '스릴러'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['코미디', '액션', '모험', '판타지'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['스릴러', '드라마', '로맨스'],
#  ['드라마'],
#  ['드라마'],
#  ['범죄'],
#  ['범죄'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  [],
#  [],
#  ['드라마', '역사'],
#  ['드라마', '서부', '모험'],
#  ['드라마', '서부', '모험'],
#  ['드라마', '판타지', 'SF'],
#  ['드라마', '판타지', 'SF'],
#  ['드라마', '스릴러', 'SF'],
#  ['드라마', '스릴러', 'SF'],
#  ['드라마', '스릴러', 'SF'],
#  ['드라마', '스릴러', 'SF'],
#  ['스릴러', '액션'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['스릴러', '액션', 'SF'],
#  ['스릴러', '액션', 'SF'],
#  ['스릴러', '액션', 'SF'],
#  ['액션', '스릴러'],
#  ['액션', '스릴러'],
#  ['코미디'],
#  ['코미디'],
#  ['스릴러', 'SF', '미스터리', '로맨스'],
#  ['스릴러', 'SF', '미스터리', '로맨스'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['SF', '스릴러'],
#  ['SF', '스릴러'],
#  ['SF'],
#  ['SF'],
#  ['SF'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['공포', 'SF', '액션', '스릴러'],
#  ['공포', 'SF', '액션', '스릴러'],
#  [],
#  [],
#  [],
#  [],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['스릴러', 'SF', '공포'],
#  ['스릴러', 'SF', '공포'],
#  ['코미디', '모험'],
#  ['코미디', '모험'],
#  ['코미디', '모험'],
#  ['코미디', '모험'],
#  ['코미디'],
#  ['코미디'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  [],
#  [],
#  [],
#  [],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [],
#  [],
#  [],
#  [],
#  ['액션', '공포', '스릴러'],
#  ['액션', '공포', '스릴러'],
#  ['스릴러', '미스터리', '범죄'],
#  ['스릴러', '미스터리', '범죄'],
#  ['서부', '코미디'],
#  ['서부', '코미디'],
#  ['액션', '모험', '스릴러'],
#  ['액션', '모험', '스릴러'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['액션', '공포'],
#  ['액션', '공포'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['액션', '코미디'],
#  ['액션', '코미디'],
#  ['액션', '코미디'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['미스터리', '스릴러', '드라마', '액션'],
#  ['애니메이션', '가족'],
#  ['애니메이션', '가족'],
#  ['스릴러', '드라마'],
#  ['스릴러', '드라마'],
#  ['드라마', '판타지', '스릴러'],
#  ['드라마', '판타지', '스릴러'],
#  ['드라마', '판타지', '스릴러'],
#  ['액션', '범죄', 'SF'],
#  ['액션', '범죄', 'SF'],
#  ['액션', '범죄', 'SF'],
#  ['액션', '범죄', 'SF'],
#  ['액션', '범죄', 'SF'],
#  ['범죄', '스릴러', '드라마'],
#  ['범죄', '스릴러', '드라마'],
#  ['범죄', '스릴러', '드라마'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['액션', '모험', '스릴러'],
#  ['액션', '모험', '스릴러'],
#  ['액션', '모험', '스릴러'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['스릴러', 'SF'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  [],
#  [],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['코미디'],
#  ['코미디'],
#  ['드라마'],
#  ['드라마'],
#  ['역사', '드라마'],
#  ['역사', '드라마'],
#  [],
#  [],
#  ['드라마', '액션', '스릴러'],
#  ['드라마', '액션', '스릴러'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['모험', '코미디', '판타지', '미스터리'],
#  ['판타지', '애니메이션', '모험'],
#  ['SF', '모험', '미스터리'],
#  ['SF', '모험', '미스터리'],
#  ['드라마'],
#  ['드라마'],
#  ['범죄', '드라마'],
#  ['범죄', '드라마'],
#  ['코미디', '서부'],
#  ['코미디', '서부'],
#  ['드라마', '코미디', '로맨스'],
#  ['드라마', '코미디', '로맨스'],
#  ['범죄', '액션', 'SF'],
#  ['범죄', '액션', 'SF'],
#  ['범죄', '액션', 'SF'],
#  ['코미디', '액션', '스릴러'],
#  ['코미디', '액션', '스릴러'],
#  [],
#  [],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['로맨스', '드라마', '역사', '코미디'],
#  ['공포', 'TV 영화'],
#  ['공포', 'TV 영화'],
#  ['액션', '드라마', 'SF'],
#  ['액션', '드라마', 'SF'],
#  ['액션', '드라마', 'SF'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러', '범죄'],
#  ['드라마', '스릴러', '범죄'],
#  ['드라마', '스릴러', '범죄'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['드라마', '로맨스'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['스릴러', '드라마'],
#  ['스릴러', '드라마'],
#  ['드라마', '범죄', '역사'],
#  ['드라마', '범죄', '역사'],
#  ['드라마', '범죄', '역사'],
#  ['드라마', '범죄', '역사'],
#  ['드라마', '코미디', '역사'],
#  ['드라마', '코미디', '역사'],
#  ['드라마', '코미디', '역사'],
#  ['스릴러', '범죄', '액션', '드라마', '역사'],
#  ['스릴러', '범죄', '액션', '드라마', '역사'],
#  ['액션', '범죄'],
#  ['액션', '범죄'],
#  ['액션', '범죄'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['코미디'],
#  ['코미디'],
#  ['판타지', '드라마', '로맨스'],
#  ['판타지', '드라마', '로맨스'],
#  ['판타지', '드라마', '로맨스'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['드라마'],
#  ['드라마'],
#  ['드라마'],
#  ['모험', '역사', '전쟁'],
#  ['모험', '역사', '전쟁'],
#  ['스릴러', '드라마', '미스터리'],
#  ['스릴러', '드라마', '미스터리'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['판타지', '로맨스'],
#  ['판타지', '로맨스'],
#  ['미스터리', '스릴러'],
#  ['미스터리', '스릴러'],
#  ['미스터리', '스릴러'],
#  ['코미디', '드라마', 'SF'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['드라마'],
#  ['드라마'],
#  [],
#  [],
#  [],
#  ['스릴러', '드라마', '미스터리'],
#  ['스릴러', '드라마', '미스터리'],
#  ['스릴러'],
#  ['스릴러'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [],
#  [],
#  ['드라마', '역사'],
#  ['드라마', '역사'],
#  ['공포', '판타지'],
#  ['공포', '판타지'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  [nan],
#  [nan],
#  [nan],
#  ['액션', '모험', '코미디', 'SF'],
#  ['액션', '모험', '코미디', 'SF'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['모험', '액션', '스릴러', 'SF'],
#  ['범죄', '미스터리', '스릴러'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['범죄', '미스터리', '스릴러'],
#  ['코미디'],
#  ['코미디'],
#  ['액션'],
#  ['액션'],
#  ['액션'],
#  ['액션'],
#  [],
#  [],
#  [],
#  ['액션', '모험', 'SF'],
#  ['액션', '모험', 'SF'],
#  ['액션', '모험', 'SF'],
#  ['액션', '모험', 'SF'],
#  ['코미디'],
#  ['코미디'],
#  ['액션', '모험', 'SF'],
#  ['액션', '모험', 'SF'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['SF', '액션', '스릴러'],
#  ['SF', '액션', '스릴러'],
#  ['액션', '코미디'],
#  ['액션', '코미디'],
#  ['애니메이션', '모험', '코미디'],
#  ['애니메이션', '모험', '코미디'],
#  ['애니메이션', '모험', '코미디'],
#  ['애니메이션', '모험', '코미디'],
#  ['애니메이션', '모험', '코미디'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['코미디', '액션', '모험', '판타지'],
#  ['코미디', '액션', '모험', '판타지'],
#  ['코미디', '액션', '모험', '판타지'],
#  ['코미디', '액션', '모험', '판타지'],
#  ['코미디', '액션', '모험', '판타지'],
#  ['코미디', '액션', '모험', '판타지'],
#  ['코미디', '범죄', '드라마', '미스터리'],
#  ['코미디', '범죄', '드라마', '미스터리'],
#  ['액션', '스릴러', '범죄'],
#  ['액션', '스릴러', '범죄'],
#  ['액션', '스릴러', '범죄'],
#  ['액션', '스릴러', '범죄'],
#  ['액션', '스릴러', '범죄'],
#  ['액션', '코미디'],
#  ['액션', '코미디'],
#  ['스릴러', '액션'],
#  ['스릴러', '액션', 'SF'],
#  ['스릴러', '액션', 'SF'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디', '로맨스', '드라마'],
#  ['코미디', '로맨스', '드라마'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['액션', '모험', '코미디', 'SF'],
#  ['액션', '모험', '코미디', 'SF'],
#  ['코미디', '미스터리', '공포'],
#  ['코미디', '미스터리', '공포'],
#  ['액션', '코미디', '범죄'],
#  ['액션', '코미디', '범죄'],
#  ['액션', '코미디', '범죄'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [],
#  [],
#  ['액션', '모험', '스릴러'],
#  ['액션', '모험', '스릴러'],
#  ['공포', '코미디'],
#  ['공포', '코미디'],
#  [],
#  [],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['액션', '코미디', '미스터리', '범죄'],
#  ['액션', '코미디', '미스터리', '범죄'],
#  ['액션', '코미디', '미스터리', '범죄'],
#  ['액션', '코미디', '미스터리', '범죄'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  ['코미디', '드라마'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['액션', '스릴러', '범죄', '모험'],
#  ['액션', '스릴러', '범죄', '모험'],
#  ['액션', '스릴러', '범죄', '모험'],
#  ['액션', '스릴러', '범죄', '모험'],
#  ['드라마', '액션', '스릴러'],
#  ['드라마', '액션', '스릴러'],
#  ['드라마', '액션', '스릴러'],
#  ['SF', '액션', '범죄', '스릴러', '드라마'],
#  ['SF', '액션', '범죄', '스릴러', '드라마'],
#  ['SF', '액션', '범죄', '스릴러', '드라마'],
#  ['드라마', '스릴러'],
#  ['드라마', '스릴러'],
#  ['드라마', '코미디', '역사'],
#  ['드라마', '코미디', '역사'],
#  ['미스터리', '액션', '범죄'],
#  ['미스터리', '액션', '범죄'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['코미디', '액션', '스릴러'],
#  ['코미디', '액션', '스릴러'],
#  ['코미디', '액션', '스릴러'],
#  ['코미디', '액션', '스릴러'],
#  ['코미디', '액션', '스릴러'],
#  ['액션', '코미디'],
#  ['액션', '코미디'],
#  ['코미디', '서부'],
#  ['코미디', '서부'],
#  ['애니메이션', '가족', '판타지'],
#  ['스릴러', '범죄'],
#  ['스릴러', '범죄'],
#  ['스릴러', '범죄'],
#  ['스릴러', '범죄'],
#  ['범죄', '코미디', '음악', '스릴러'],
#  ['범죄', '코미디', '음악', '스릴러'],
#  ['범죄', '코미디', '음악', '스릴러'],
#  ['범죄', '코미디', '음악', '스릴러'],
#  ['SF', '액션', '스릴러'],
#  ['SF', '액션', '스릴러'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  [],
#  [],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['공포', '미스터리'],
#  ['범죄', '액션', 'SF'],
#  ['범죄', '액션', 'SF'],
#  ['범죄', '액션', 'SF'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['액션', '범죄'],
#  ['액션', '범죄'],
#  ['코미디', '액션', '모험'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디', '액션', '모험'],
#  ['코미디', '액션', '모험'],
#  ['코미디', '액션', '모험'],
#  ['코미디', '액션', '모험'],
#  ['코미디', '액션', '모험'],
#  [nan],
#  [nan],
#  [nan],
#  ['다큐멘터리'],
#  [],
#  [],
#  [],
#  ['가족', '애니메이션', '모험', '코미디', '판타지'],
#  ['가족', '애니메이션', '모험', '코미디', '판타지'],
#  ['코미디', '공포'],
#  ['코미디', '공포'],
#  ['공포'],
#  ['공포'],
#  ['SF', '액션', '공포'],
#  ['SF', '액션', '공포'],
#  ['공포', '코미디'],
#  ['공포', '코미디'],
#  ['모험', 'SF'],
#  ['모험', 'SF'],
#  ['모험', 'SF'],
#  ['범죄', '코미디'],
#  ['범죄', '코미디'],
#  ['범죄', '코미디'],
#  ['액션', '모험', '애니메이션', '가족'],
#  ['액션', '모험', '애니메이션', '가족'],
#  ['액션', '코미디'],
#  ['액션', '코미디'],
#  [],
#  [],
#  [],
#  ['코미디'],
#  ['코미디'],
#  ['SF', '모험', '액션', '코미디'],
#  ['SF', '모험', '액션', '코미디'],
#  ['SF', '모험', '액션', '코미디'],
#  ['SF', '모험', '액션', '코미디'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['SF', '드라마'],
#  ['SF', '미스터리', '모험'],
#  ['SF', '미스터리', '모험'],
#  ['SF', '드라마'],
#  ['액션', '모험', 'SF'],
#  ['액션', '모험', 'SF'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디'],
#  ['공포', '코미디'],
#  ['공포', '코미디'],
#  ['공포', '코미디'],
#  ['코미디', '판타지', '로맨스'],
#  ['코미디', '판타지', '로맨스'],
#  ['코미디', '판타지', '로맨스'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['드라마', '범죄'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['로맨스', '코미디'],
#  ['코미디', '판타지', '로맨스'],
#  ['코미디', '판타지', '로맨스'],
#  ['코미디', '판타지', '로맨스'],
#  ['코미디', '판타지', '로맨스'],
#  ['코미디', '판타지', '로맨스'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['판타지', '코미디', '로맨스'],
#  ['판타지', '코미디', '로맨스'],
#  ['로맨스', '드라마'],
#  ['로맨스', '드라마'],
#  ['로맨스', '드라마'],
#  ['스릴러', '드라마', 'SF'],
#  ['스릴러', '드라마', 'SF'],
#  [],
#  [],
#  ['코미디'],
#  ['코미디'],
#  ['판타지', '액션', '스릴러'],
#  ['판타지', '액션', '스릴러'],
#  ['판타지', '액션', '스릴러'],
#  ['액션', '범죄'],
#  ['액션', '범죄'],
#  [],
#  [],
#  ['모험', '드라마', 'SF'],
#  ['모험', '드라마', 'SF'],
#  [],
#  [],
#  [],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  [],
#  [],
#  [],
#  ['로맨스', '드라마'],
#  ['로맨스', '드라마'],
#  ['로맨스', '드라마'],
#  ['TV 영화', '로맨스'],
#  ['TV 영화', '로맨스'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  [],
#  [],
#  ['애니메이션', '모험', '코미디'],
#  ['애니메이션', '모험', '코미디'],
#  ['드라마', '스릴러'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['다큐멘터리'],
#  ['애니메이션', '로맨스', '드라마'],
#  ['애니메이션', '로맨스', '드라마'],
#  ['애니메이션', '로맨스', '드라마'],
#  ['애니메이션', '액션', '모험', '가족', '판타지', '로맨스'],
#  ['애니메이션', '액션', '모험', '가족', '판타지', '로맨스'],
#  ['판타지', '애니메이션', '가족'],
#  ['판타지', '애니메이션', '가족'],
#  ['코미디'],
#  ['코미디'],
#  ['코미디', '로맨스'],
#  ['코미디', '로맨스'],
#  ['모험', '판타지'],
#  ['판타지', '모험', '가족', '드라마'],
#  ['모험', '판타지'],
#  ['판타지', '모험', '가족', '드라마'],
#  ['애니메이션', '가족', '판타지'],
#  ['애니메이션', '가족', '판타지'],
#  ['다큐멘터리'],
#  [nan],
#  ['다큐멘터리'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['드라마', '판타지', 'SF'],
#  ['드라마', '판타지', 'SF'],
#  ['드라마'],
#  ['드라마'],
#  ['코미디', '음악', '가족'],
#  ['코미디', '음악', '가족'],
#  ['코미디', '음악', '가족'],
#  ['가족', '애니메이션', '모험', '코미디'],
#  ['가족', '애니메이션', '모험', '코미디'],
#  ['코미디', '음악', '가족'],
#  ['코미디', '음악', '가족'],
#  ['다큐멘터리', '드라마'],
#  ['다큐멘터리', '드라마'],
#  [nan],
#  [nan],
#  [nan],
#  [nan],
#  ['가족', '애니메이션', '코미디'],
#  ['가족', '애니메이션', '코미디'],
#  ...]

# %%
len(genres_list)
# Out:
# 1032

# %%
genres = pd.DataFrame(genres_list, columns = ["genre1", "genre2", "genre3", "genre4", "genre5", "genre6"])
genres
# Out:
#      genre1 genre2 genre3 genre4 genre5 genre6
# 0      미스터리     범죄     SF   None   None   None
# 1      미스터리     범죄     SF   None   None   None
# 2       코미디    로맨스   None   None   None   None
# 3       로맨스    코미디   None   None   None   None
# 4       로맨스    코미디   None   None   None   None
# ...     ...    ...    ...    ...    ...    ...
# 1027    NaN   None   None   None   None   None
# 1028    NaN   None   None   None   None   None
# 1029    NaN   None   None   None   None   None
# 1030    코미디    드라마    로맨스   None   None   None
# 1031    코미디    드라마    로맨스   None   None   None
#
# [1032 rows x 6 columns]

# %%
len(genres)
# Out:
# 1032

# %%
g1 = (genres["genre1"].value_counts())

# %%
g1 =pd.DataFrame(genres["genre1"].value_counts())

# %%
g2 =pd.DataFrame(genres["genre2"].value_counts())

# %%
g3 =pd.DataFrame(genres["genre3"].value_counts())

# %%
g4 =pd.DataFrame(genres["genre4"].value_counts())

# %%
g5 =pd.DataFrame(genres["genre5"].value_counts())

# %%
g6 =pd.DataFrame(genres["genre6"].value_counts())

# %%
genre_total = pd.concat([g1,g2,g3,g4,g5,g6], axis=1)
genre_total
# Out:
#        genre1  genre2  genre3  genre4  genre5  genre6
# 드라마     165.0    98.0    45.0     6.0     3.0     NaN
# 코미디     146.0   118.0    15.0    12.0     NaN     NaN
# 액션       85.0    75.0    19.0     8.0     NaN     NaN
# 스릴러      65.0    58.0    43.0    17.0     NaN     NaN
# 로맨스      51.0    51.0    36.0     2.0     NaN     2.0
# 다큐멘터리    44.0     NaN     NaN     NaN     NaN     NaN
# 범죄       41.0    40.0    26.0     4.0     5.0     NaN
# SF       39.0    29.0    50.0    12.0     NaN     NaN
# 애니메이션    34.0    17.0     4.0     NaN     NaN     NaN
# 모험       33.0    43.0    36.0     4.0     NaN     NaN
# 공포       31.0     6.0     6.0     5.0     NaN     NaN
# 판타지      27.0    28.0    20.0     9.0     4.0     NaN
# 미스터리     17.0    35.0    18.0    14.0     NaN     NaN
# 가족        8.0    12.0    21.0     7.0     2.0     NaN
# 역사        6.0    15.0    15.0     NaN     5.0     NaN
# 전쟁        3.0     NaN     2.0     NaN     NaN     NaN
# 서부        2.0     8.0     NaN     NaN     NaN     NaN
# TV 영화     2.0     2.0     2.0     NaN     NaN     NaN
# 음악        NaN     5.0     7.0     NaN     NaN     NaN

# %%
genre_total["sum"] = genre_total.sum(axis=1)
genre_total.reset_index().rename(columns={"index":"genre"})
# Out:
#     genre  genre1  genre2  genre3  genre4  genre5  genre6    sum
# 0     드라마   165.0    98.0    45.0     6.0     3.0     NaN  317.0
# 1     코미디   146.0   118.0    15.0    12.0     NaN     NaN  291.0
# 2      액션    85.0    75.0    19.0     8.0     NaN     NaN  187.0
# 3     스릴러    65.0    58.0    43.0    17.0     NaN     NaN  183.0
# 4     로맨스    51.0    51.0    36.0     2.0     NaN     2.0  142.0
# 5   다큐멘터리    44.0     NaN     NaN     NaN     NaN     NaN   44.0
# 6      범죄    41.0    40.0    26.0     4.0     5.0     NaN  116.0
# 7      SF    39.0    29.0    50.0    12.0     NaN     NaN  130.0
# 8   애니메이션    34.0    17.0     4.0     NaN     NaN     NaN   55.0
# 9      모험    33.0    43.0    36.0     4.0     NaN     NaN  116.0
# 10     공포    31.0     6.0     6.0     5.0     NaN     NaN   48.0
# 11    판타지    27.0    28.0    20.0     9.0     4.0     NaN   88.0
# 12   미스터리    17.0    35.0    18.0    14.0     NaN     NaN   84.0
# 13     가족     8.0    12.0    21.0     7.0     2.0     NaN   50.0
# 14     역사     6.0    15.0    15.0     NaN     5.0     NaN   41.0
# 15     전쟁     3.0     NaN     2.0     NaN     NaN     NaN    5.0
# 16     서부     2.0     8.0     NaN     NaN     NaN     NaN   10.0
# 17  TV 영화     2.0     2.0     2.0     NaN     NaN     NaN    6.0
# 18     음악     NaN     5.0     7.0     NaN     NaN     NaN   12.0

# %%
genre_total = genre_total.sort_values(by=["sum"],ascending=False)
genre_total
# Out:
#        genre1  genre2  genre3  genre4  genre5  genre6    sum
# 드라마     165.0    98.0    45.0     6.0     3.0     NaN  317.0
# 코미디     146.0   118.0    15.0    12.0     NaN     NaN  291.0
# 액션       85.0    75.0    19.0     8.0     NaN     NaN  187.0
# 스릴러      65.0    58.0    43.0    17.0     NaN     NaN  183.0
# 로맨스      51.0    51.0    36.0     2.0     NaN     2.0  142.0
# SF       39.0    29.0    50.0    12.0     NaN     NaN  130.0
# 모험       33.0    43.0    36.0     4.0     NaN     NaN  116.0
# 범죄       41.0    40.0    26.0     4.0     5.0     NaN  116.0
# 판타지      27.0    28.0    20.0     9.0     4.0     NaN   88.0
# 미스터리     17.0    35.0    18.0    14.0     NaN     NaN   84.0
# 애니메이션    34.0    17.0     4.0     NaN     NaN     NaN   55.0
# 가족        8.0    12.0    21.0     7.0     2.0     NaN   50.0
# 공포       31.0     6.0     6.0     5.0     NaN     NaN   48.0
# 다큐멘터리    44.0     NaN     NaN     NaN     NaN     NaN   44.0
# 역사        6.0    15.0    15.0     NaN     5.0     NaN   41.0
# 음악        NaN     5.0     7.0     NaN     NaN     NaN   12.0
# 서부        2.0     8.0     NaN     NaN     NaN     NaN   10.0
# TV 영화     2.0     2.0     2.0     NaN     NaN     NaN    6.0
# 전쟁        3.0     NaN     2.0     NaN     NaN     NaN    5.0

# %% [markdown]
# ### Top5 추출

# %%
top5 = genre_total.iloc[:5]
top5 = top5.reset_index()
top5 = top5.fillna(value =0)
top5
# Out:
#   index  genre1  genre2  genre3  genre4  genre5  genre6    sum
# 0   드라마   165.0    98.0    45.0     6.0     3.0     0.0  317.0
# 1   코미디   146.0   118.0    15.0    12.0     0.0     0.0  291.0
# 2    액션    85.0    75.0    19.0     8.0     0.0     0.0  187.0
# 3   스릴러    65.0    58.0    43.0    17.0     0.0     0.0  183.0
# 4   로맨스    51.0    51.0    36.0     2.0     0.0     2.0  142.0

# %% [markdown]
# ### Radar chart
#
# https://blog.naver.com/breezehome50/222305541524 참고

# %%
categories = top5["index"]
categories = [*categories, categories[0]]

top5_sum = top5["sum"]
sum = [*top5_sum, top5_sum[0]]


label_loc = np.linspace(start=0, stop=2*np.pi, num=len(sum))


plt.figure(figsize=(8,8))
ax = plt.subplot(polar=True)
plt.xticks(label_loc, labels=categories, fontsize=13)
ax.plot(label_loc, sum, label='genre', linestyle='dashed', color='lightcoral')
ax.fill(label_loc, sum, color='lightcoral', alpha=0.3)
ax.legend()
plt.show()
